# %% [markdown]
# This code will:
#
# Loop through each date from {Start Date} to {End Date} entered in variables.
# For each date, call your existing fetch_and_save_final_boxscores() function
# Save individual files for each day:
# JSON: data/json/boxscores/mlb_boxscores_{date}.json
# CSV: data/csv/boxscores/mlb_boxscores_{date}.csv
# Create a combined CSV with all batting data from the entire date range
# Handle errors gracefully if any dates fail to process

# %%
import requests
import pandas as pd
import json
import os
from datetime import datetime, timedelta

def fetch_and_save_final_boxscores(date_str):
    csv_path = f'data/csv/games/mlb_games_{date_str}.csv'
    json_path = f'data/json/boxscores/mlb_boxscores_{date_str}.json'
    csv_output_path = f'data/csv/boxscores/mlb_boxscores_{date_str}.csv'

    if not os.path.exists(csv_path):
        print(f"CSV file not found: {csv_path}")
        return

    games_df = pd.read_csv(csv_path)
    all_boxscores = []
    
    for game_pk in games_df['gamePk']:
        url = f'https://statsapi.mlb.com/api/v1/game/{game_pk}/boxscore'
        response = requests.get(url)
        if response.status_code == 200:
            boxscore_data = response.json()
            all_boxscores.append({'gamePk': game_pk, 'boxscore': boxscore_data})
        else:
            all_boxscores.append({'gamePk': game_pk, 'boxscore': None})
    
    # Ensure directories exist
    os.makedirs(os.path.dirname(json_path), exist_ok=True)
    os.makedirs('data/csv/boxscores', exist_ok=True)
    
    # Save JSON
    with open(json_path, 'w') as f:
        json.dump(all_boxscores, f, indent=2)
    
    # Convert to CSV - flatten batting data for all players
    batting_rows = []
    for game in all_boxscores:
        if game['boxscore']:
            for team_type in ['home', 'away']:
                team = game['boxscore']['teams'][team_type]
                batters = team.get('batters', [])
                players = team.get('players', {})
                
                for batter_id in batters:
                    player_key = f"ID{batter_id}"
                    player = players.get(player_key, {})
                    if player:
                        person = player.get('person', {})
                        stats = player.get('stats', {}).get('batting', {})
                        
                        row = {
                            'gamePk': game['gamePk'],
                            'team': team['team']['name'],
                            'team_type': team_type,
                            'player_id': person.get('id'),
                            'player_name': person.get('fullName'),
                            'batting_order': player.get('battingOrder'),
                            'gamesPlayed': stats.get('gamesPlayed'),
                            'atBats': stats.get('atBats'),
                            'hits': stats.get('hits'),
                            'runs': stats.get('runs'),
                            'doubles': stats.get('doubles'),
                            'triples': stats.get('triples'),
                            'homeRuns': stats.get('homeRuns'),
                            'rbi': stats.get('rbi'),
                            'baseOnBalls': stats.get('baseOnBalls'),
                            'strikeOuts': stats.get('strikeOuts'),
                            'leftOnBase': stats.get('leftOnBase'),
                        }
                        batting_rows.append(row)
    
    # Create and save CSV
    df = pd.DataFrame(batting_rows)
    df.to_csv(csv_output_path, index=False)
    print(f"Saved boxscore data to {csv_output_path}")

# Define date range
start_date = datetime(2025, 9, 1)
end_date = datetime(2025, 9, 30)

# Generate list of dates
date_range = []
current_date = start_date
while current_date <= end_date:
    date_range.append(current_date.strftime('%Y-%m-%d'))
    current_date += timedelta(days=1)

print(f"Processing boxscores for dates: {date_range}")

# Process each date
all_batting_data = []
for date_str in date_range:
    print(f"Processing boxscores for {date_str}...")
    
    try:
        fetch_and_save_final_boxscores(date_str)
        
        # Read the individual CSV to add to combined dataset
        csv_path = f'data/csv/boxscores/mlb_boxscores_{date_str}.csv'
        if os.path.exists(csv_path):
            daily_df = pd.read_csv(csv_path)
            daily_df['date'] = date_str
            all_batting_data.append(daily_df)
            print(f"  - Processed {len(daily_df)} batting records for {date_str}")
        
    except Exception as e:
        print(f"  - Error processing {date_str}: {e}")

# Combine all batting data into one master CSV
if all_batting_data:
    combined_df = pd.concat(all_batting_data, ignore_index=True)
    combined_df.to_csv('data/csv/boxscores/mlb_boxscores_2025-07-06_to_2025-07-18.csv', index=False)
    print(f"\nCombined boxscore data saved: {len(combined_df)} total batting records")
    print(f"File: data/csv/boxscores/mlb_boxscores_2025-07-06_to_2025-07-18.csv")
else:
    print("No boxscore data found for the date range")
# Out:
# Processing boxscores for dates: ['2025-09-01', '2025-09-02', '2025-09-03', '2025-09-04', '2025-09-05', '2025-09-06', '2025-09-07', '2025-09-08', '2025-09-09', '2025-09-10', '2025-09-11', '2025-09-12', '2025-09-13', '2025-09-14', '2025-09-15', '2025-09-16', '2025-09-17', '2025-09-18', '2025-09-19', '2025-09-20', '2025-09-21', '2025-09-22', '2025-09-23', '2025-09-24', '2025-09-25', '2025-09-26', '2025-09-27', '2025-09-28', '2025-09-29', '2025-09-30']
# Processing boxscores for 2025-09-01...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-01.csv
#   - Processed 416 batting records for 2025-09-01
# Processing boxscores for 2025-09-02...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-02.csv
#   - Processed 428 batting records for 2025-09-02
# Processing boxscores for 2025-09-03...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-03.csv
#   - Processed 447 batting records for 2025-09-03
# Processing boxscores for 2025-09-04...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-04.csv
#   - Processed 181 batting records for 2025-09-04
# Processing boxscores for 2025-09-05...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-05.csv
#   - Processed 448 batting records for 2025-09-05
# Processing boxscores for 2025-09-06...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-06.csv
#   - Processed 441 batting records for 2025-09-06
# Processing boxscores for 2025-09-07...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-07.csv
#   - Processed 471 batting records for 2025-09-07
# Processing boxscores for 2025-09-08...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-08.csv
#   - Processed 309 batting records for 2025-09-08
# Processing boxscores for 2025-09-09...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-09.csv
#   - Processed 446 batting records for 2025-09-09
# Processing boxscores for 2025-09-10...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-10.csv
#   - Processed 486 batting records for 2025-09-10
# Processing boxscores for 2025-09-11...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-11.csv
#   - Processed 263 batting records for 2025-09-11
# Processing boxscores for 2025-09-12...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-12.csv
#   - Processed 441 batting records for 2025-09-12
# Processing boxscores for 2025-09-13...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-13.csv
#   - Processed 475 batting records for 2025-09-13
# Processing boxscores for 2025-09-14...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-14.csv
#   - Processed 459 batting records for 2025-09-14
# Processing boxscores for 2025-09-15...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-15.csv
#   - Processed 275 batting records for 2025-09-15
# Processing boxscores for 2025-09-16...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-16.csv
#   - Processed 487 batting records for 2025-09-16
# Processing boxscores for 2025-09-17...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-17.csv
#   - Processed 466 batting records for 2025-09-17
# Processing boxscores for 2025-09-18...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-18.csv
#   - Processed 286 batting records for 2025-09-18
# Processing boxscores for 2025-09-19...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-19.csv
#   - Processed 464 batting records for 2025-09-19
# Processing boxscores for 2025-09-20...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-20.csv
#   - Processed 472 batting records for 2025-09-20
# Processing boxscores for 2025-09-21...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-21.csv
#   - Processed 475 batting records for 2025-09-21
# Processing boxscores for 2025-09-22...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-22.csv
#   - Processed 95 batting records for 2025-09-22
# Processing boxscores for 2025-09-23...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-23.csv
#   - Processed 471 batting records for 2025-09-23
# Processing boxscores for 2025-09-24...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-24.csv
#   - Processed 447 batting records for 2025-09-24
# Processing boxscores for 2025-09-25...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-25.csv
#   - Processed 375 batting records for 2025-09-25
# Processing boxscores for 2025-09-26...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-26.csv
#   - Processed 458 batting records for 2025-09-26
# Processing boxscores for 2025-09-27...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-27.csv
#   - Processed 440 batting records for 2025-09-27
# Processing boxscores for 2025-09-28...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-28.csv
#   - Processed 475 batting records for 2025-09-28
# Processing boxscores for 2025-09-29...
# CSV file not found: data/csv/games/mlb_games_2025-09-29.csv
# Processing boxscores for 2025-09-30...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-09-30.csv
#   - Processed 120 batting records for 2025-09-30
#
# Combined boxscore data saved: 11517 total batting records
# File: data/csv/boxscores/mlb_boxscores_2025-07-06_to_2025-07-18.csv
