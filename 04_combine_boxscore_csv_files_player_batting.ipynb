# %%
import pandas as pd
import os
import glob

def combine_csv_files(folder_path, output_file):
    """
    Combine all CSV files in a folder into one CSV file
    
    Args:
        folder_path (str): Path to folder containing CSV files
        output_file (str): Path for the combined output CSV file
    """
    # Get all CSV files in the folder
    csv_files = glob.glob(os.path.join(folder_path, "*.csv"))
    
    if not csv_files:
        print(f"No CSV files found in {folder_path}")
        return
    
    print(f"Found {len(csv_files)} CSV files to combine:")
    for file in csv_files:
        print(f"  - {os.path.basename(file)}")
    
    # Read and combine all CSV files
    combined_data = []
    total_rows = 0
    
    for file in csv_files:
        try:
            df = pd.read_csv(file)
            combined_data.append(df)
            total_rows += len(df)
            print(f"  - Loaded {len(df)} rows from {os.path.basename(file)}")
        except Exception as e:
            print(f"  - Error reading {file}: {e}")
    
    if combined_data:
        # Combine all DataFrames
        combined_df = pd.concat(combined_data, ignore_index=True)
        
        # Save to output file
        combined_df.to_csv(output_file, index=False)
        print(f"\nCombined {len(csv_files)} files into {output_file}")
        print(f"Total rows: {total_rows}")
        print(f"Combined DataFrame shape: {combined_df.shape}")
    else:
        print("No data to combine")

# Example usage for your boxscore files
if __name__ == "__main__":
    # Combine all boxscore CSV files
    folder_path = "data/csv/boxscores"
    output_file = "data/csv/boxscores/combined_boxscores.csv"
    
    combine_csv_files(folder_path, output_file)
    
    # Or combine game files
    # folder_path = "data/csv/games"
    # output_file = "data/csv/games/combined_games.csv"
    # combine_csv_files(folder_path, output_file)
# Out:
# Found 186 CSV files to combine:
#   - combined_boxscores.csv
#   - mlb_boxscores_2025-03-27.csv
#   - mlb_boxscores_2025-03-28.csv
#   - mlb_boxscores_2025-03-29.csv
#   - mlb_boxscores_2025-03-30.csv
#   - mlb_boxscores_2025-03-31.csv
#   - mlb_boxscores_2025-04-01.csv
#   - mlb_boxscores_2025-04-02.csv
#   - mlb_boxscores_2025-04-03.csv
#   - mlb_boxscores_2025-04-04.csv
#   - mlb_boxscores_2025-04-05.csv
#   - mlb_boxscores_2025-04-06.csv
#   - mlb_boxscores_2025-04-07.csv
#   - mlb_boxscores_2025-04-08.csv
#   - mlb_boxscores_2025-04-09.csv
#   - mlb_boxscores_2025-04-10.csv
#   - mlb_boxscores_2025-04-11.csv
#   - mlb_boxscores_2025-04-12.csv
#   - mlb_boxscores_2025-04-13.csv
#   - mlb_boxscores_2025-04-14.csv
#   - mlb_boxscores_2025-04-15.csv
#   - mlb_boxscores_2025-04-16.csv
#   - mlb_boxscores_2025-04-17.csv
#   - mlb_boxscores_2025-04-18.csv
#   - mlb_boxscores_2025-04-19.csv
#   - mlb_boxscores_2025-04-20.csv
#   - mlb_boxscores_2025-04-21.csv
#   - mlb_boxscores_2025-04-22.csv
#   - mlb_boxscores_2025-04-23.csv
#   - mlb_boxscores_2025-04-24.csv
#   - mlb_boxscores_2025-04-25.csv
#   - mlb_boxscores_2025-04-26.csv
#   - mlb_boxscores_2025-04-27.csv
#   - mlb_boxscores_2025-04-28.csv
#   - mlb_boxscores_2025-04-29.csv
#   - mlb_boxscores_2025-04-30.csv
#   - mlb_boxscores_2025-05-01.csv
#   - mlb_boxscores_2025-09-22.csv
#   - mlb_boxscores_2025-09-23.csv
#   - mlb_boxscores_2025-09-24.csv
#   - mlb_boxscores_2025-09-25.csv
#   - mlb_boxscores_2025-09-26.csv
#   - mlb_boxscores_2025-09-27.csv
#   - mlb_boxscores_2025-09-28.csv
#   - mlb_boxscores_2025-09-30.csv
# C:\Users\metsy\AppData\Local\Temp\ipykernel_14120\971632396.py:30: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#   - Loaded 68448 rows from combined_boxscores.csv
#   - Loaded 420 rows from mlb_boxscores_2025-03-27.csv
#   - Loaded 259 rows from mlb_boxscores_2025-03-28.csv
#   - Loaded 467 rows from mlb_boxscores_2025-03-29.csv
#   - Loaded 386 rows from mlb_boxscores_2025-03-30.csv
#   - Loaded 415 rows from mlb_boxscores_2025-03-31.csv
#   - Loaded 380 rows from mlb_boxscores_2025-04-01.csv
#   - Loaded 438 rows from mlb_boxscores_2025-04-02.csv
#   - Loaded 144 rows from mlb_boxscores_2025-04-03.csv
#   - Loaded 415 rows from mlb_boxscores_2025-04-04.csv
#   - Loaded 401 rows from mlb_boxscores_2025-04-05.csv
#   - Loaded 468 rows from mlb_boxscores_2025-04-06.csv
#   - Loaded 295 rows from mlb_boxscores_2025-04-07.csv
#   - Loaded 447 rows from mlb_boxscores_2025-04-08.csv
#   - Loaded 452 rows from mlb_boxscores_2025-04-09.csv
#   - Loaded 182 rows from mlb_boxscores_2025-04-10.csv
#   - Loaded 369 rows from mlb_boxscores_2025-04-11.csv
#   - Loaded 431 rows from mlb_boxscores_2025-04-12.csv
#   - Loaded 434 rows from mlb_boxscores_2025-04-13.csv
#   - Loaded 279 rows from mlb_boxscores_2025-04-14.csv
#   - Loaded 425 rows from mlb_boxscores_2025-04-15.csv
#   - Loaded 444 rows from mlb_boxscores_2025-04-16.csv
#   - Loaded 288 rows from mlb_boxscores_2025-04-17.csv
#   - Loaded 411 rows from mlb_boxscores_2025-04-18.csv
#   - Loaded 440 rows from mlb_boxscores_2025-04-19.csv
#   - Loaded 471 rows from mlb_boxscores_2025-04-20.csv
#   - Loaded 219 rows from mlb_boxscores_2025-04-21.csv
#   - Loaded 441 rows from mlb_boxscores_2025-04-22.csv
#   - Loaded 421 rows from mlb_boxscores_2025-04-23.csv
#   - Loaded 233 rows from mlb_boxscores_2025-04-24.csv
#   - Loaded 368 rows from mlb_boxscores_2025-04-25.csv
#   - Loaded 471 rows from mlb_boxscores_2025-04-26.csv
#   - Loaded 454 rows from mlb_boxscores_2025-04-27.csv
#   - Loaded 240 rows from mlb_boxscores_2025-04-28.csv
#   - Loaded 402 rows from mlb_boxscores_2025-04-29.csv
#   - Loaded 471 rows from mlb_boxscores_2025-04-30.csv
#   - Loaded 318 rows from mlb_boxscores_2025-05-01.csv
#   - Loaded 428 rows from mlb_boxscores_2025-05-02.csv
#   - Loaded 401 rows from mlb_boxscores_2025-05-03.csv
#   - Loaded 455 rows from mlb_boxscores_2025-05-04.csv
#   - Loaded 265 rows from mlb_boxscores_2025-05-05.csv
#   - Loaded 456 rows from mlb_boxscores_2025-05-06.csv
#   - Loaded 443 rows from mlb_boxscores_2025-05-07.csv
#   - Loaded 262 rows from mlb_boxscores_2025-05-08.csv
#   - Loaded 440 rows from mlb_boxscores_2025-05-09.csv
#   - Loaded 443 rows from mlb_boxscores_2025-05-10.csv
#   - Loaded 440 rows from mlb_boxscores_2025-05-11.csv
#   - Loaded 319 rows from mlb_boxscores_2025-05-12.csv
#   - Loaded 394 rows from mlb_boxscores_2025-05-13.csv
#   - Loaded 509 rows from mlb_boxscores_2025-05-14.csv
#   - Loaded 154 rows from mlb_boxscores_2025-05-15.csv
#   - Loaded 432 rows from mlb_boxscores_2025-05-16.csv
#   - Loaded 447 rows from mlb_boxscores_2025-05-17.csv
#   - Loaded 424 rows from mlb_boxscores_2025-05-18.csv
#   - Loaded 345 rows from mlb_boxscores_2025-05-19.csv
#   - Loaded 404 rows from mlb_boxscores_2025-05-20.csv
#   - Loaded 448 rows from mlb_boxscores_2025-05-21.csv
#   - Loaded 249 rows from mlb_boxscores_2025-05-22.csv
#   - Loaded 454 rows from mlb_boxscores_2025-05-23.csv
#   - Loaded 465 rows from mlb_boxscores_2025-05-24.csv
#   - Loaded 427 rows from mlb_boxscores_2025-05-25.csv
#   - Loaded 343 rows from mlb_boxscores_2025-05-26.csv
#   - Loaded 432 rows from mlb_boxscores_2025-05-27.csv
#   - Loaded 410 rows from mlb_boxscores_2025-05-28.csv
#   - Loaded 156 rows from mlb_boxscores_2025-05-29.csv
#   - Loaded 428 rows from mlb_boxscores_2025-05-30.csv
#   - Loaded 436 rows from mlb_boxscores_2025-05-31.csv
#   - Loaded 437 rows from mlb_boxscores_2025-06-01.csv
#   - Loaded 210 rows from mlb_boxscores_2025-06-02.csv
#   - Loaded 444 rows from mlb_boxscores_2025-06-03.csv
#   - Loaded 407 rows from mlb_boxscores_2025-06-04.csv
#   - Loaded 388 rows from mlb_boxscores_2025-06-05.csv
#   - Loaded 453 rows from mlb_boxscores_2025-06-06.csv
#   - Loaded 479 rows from mlb_boxscores_2025-06-07.csv
#   - Loaded 434 rows from mlb_boxscores_2025-06-08.csv
#   - Loaded 282 rows from mlb_boxscores_2025-06-09.csv
#   - Loaded 427 rows from mlb_boxscores_2025-06-10.csv
#   - Loaded 427 rows from mlb_boxscores_2025-06-11.csv
#   - Loaded 224 rows from mlb_boxscores_2025-06-12.csv
#   - Loaded 437 rows from mlb_boxscores_2025-06-13.csv
#   - Loaded 437 rows from mlb_boxscores_2025-06-14.csv
#   - Loaded 440 rows from mlb_boxscores_2025-06-15.csv
#   - Loaded 202 rows from mlb_boxscores_2025-06-16.csv
#   - Loaded 447 rows from mlb_boxscores_2025-06-17.csv
#   - Loaded 323 rows from mlb_boxscores_2025-06-18.csv
#   - Loaded 479 rows from mlb_boxscores_2025-06-19.csv
#   - Loaded 449 rows from mlb_boxscores_2025-06-20.csv
#   - Loaded 425 rows from mlb_boxscores_2025-06-21.csv
#   - Loaded 441 rows from mlb_boxscores_2025-06-22.csv
#   - Loaded 241 rows from mlb_boxscores_2025-06-23.csv
#   - Loaded 455 rows from mlb_boxscores_2025-06-24.csv
#   - Loaded 424 rows from mlb_boxscores_2025-06-25.csv
#   - Loaded 252 rows from mlb_boxscores_2025-06-26.csv
#   - Loaded 445 rows from mlb_boxscores_2025-06-27.csv
#   - Loaded 431 rows from mlb_boxscores_2025-06-28.csv
#   - Loaded 441 rows from mlb_boxscores_2025-06-29.csv
#   - Loaded 232 rows from mlb_boxscores_2025-06-30.csv
#   - Loaded 343 rows from mlb_boxscores_2025-07-01.csv
#   - Loaded 556 rows from mlb_boxscores_2025-07-02.csv
#   - Loaded 281 rows from mlb_boxscores_2025-07-03.csv
#   - Loaded 439 rows from mlb_boxscores_2025-07-04.csv
#   - Loaded 450 rows from mlb_boxscores_2025-07-05.csv
#   - Loaded 445 rows from mlb_boxscores_2025-07-06.csv
#   - Loaded 11517 rows from mlb_boxscores_2025-07-06_to_2025-07-18.csv
#   - Loaded 287 rows from mlb_boxscores_2025-07-07.csv
#   - Loaded 410 rows from mlb_boxscores_2025-07-08.csv
#   - Loaded 400 rows from mlb_boxscores_2025-07-09.csv
#   - Loaded 298 rows from mlb_boxscores_2025-07-10.csv
#   - Loaded 472 rows from mlb_boxscores_2025-07-11.csv
#   - Loaded 444 rows from mlb_boxscores_2025-07-12.csv
#   - Loaded 446 rows from mlb_boxscores_2025-07-13.csv
#   - Loaded 65 rows from mlb_boxscores_2025-07-15.csv
#   - Loaded 440 rows from mlb_boxscores_2025-07-18.csv
#   - Loaded 443 rows from mlb_boxscores_2025-07-19.csv
#   - Loaded 422 rows from mlb_boxscores_2025-07-20.csv
#   - Loaded 425 rows from mlb_boxscores_2025-07-21.csv
#   - Loaded 436 rows from mlb_boxscores_2025-07-22.csv
#   - Loaded 445 rows from mlb_boxscores_2025-07-23.csv
#   - Loaded 151 rows from mlb_boxscores_2025-07-24.csv
#   - Loaded 417 rows from mlb_boxscores_2025-07-25.csv
#   - Loaded 470 rows from mlb_boxscores_2025-07-26.csv
#   - Loaded 436 rows from mlb_boxscores_2025-07-27.csv
#   - Loaded 439 rows from mlb_boxscores_2025-07-28.csv
#   - Loaded 470 rows from mlb_boxscores_2025-07-29.csv
#   - Loaded 444 rows from mlb_boxscores_2025-07-30.csv
#   - Loaded 90 rows from mlb_boxscores_2025-07-31.csv
#   - Loaded 436 rows from mlb_boxscores_2025-08-01.csv
#   - Loaded 447 rows from mlb_boxscores_2025-08-02.csv
#   - Loaded 439 rows from mlb_boxscores_2025-08-03.csv
#   - Loaded 392 rows from mlb_boxscores_2025-08-04.csv
#   - Loaded 431 rows from mlb_boxscores_2025-08-05.csv
#   - Loaded 440 rows from mlb_boxscores_2025-08-06.csv
#   - Loaded 126 rows from mlb_boxscores_2025-08-07.csv
#   - Loaded 416 rows from mlb_boxscores_2025-08-08.csv
#   - Loaded 475 rows from mlb_boxscores_2025-08-09.csv
#   - Loaded 456 rows from mlb_boxscores_2025-08-10.csv
#   - Loaded 324 rows from mlb_boxscores_2025-08-11.csv
#   - Loaded 433 rows from mlb_boxscores_2025-08-12.csv
#   - Loaded 446 rows from mlb_boxscores_2025-08-13.csv
#   - Loaded 204 rows from mlb_boxscores_2025-08-14.csv
#   - Loaded 449 rows from mlb_boxscores_2025-08-15.csv
#   - Loaded 442 rows from mlb_boxscores_2025-08-16.csv
#   - Loaded 462 rows from mlb_boxscores_2025-08-17.csv
#   - Loaded 347 rows from mlb_boxscores_2025-08-18.csv
#   - Loaded 467 rows from mlb_boxscores_2025-08-19.csv
#   - Loaded 409 rows from mlb_boxscores_2025-08-20.csv
#   - Loaded 271 rows from mlb_boxscores_2025-08-21.csv
#   - Loaded 443 rows from mlb_boxscores_2025-08-22.csv
#   - Loaded 402 rows from mlb_boxscores_2025-08-23.csv
#   - Loaded 442 rows from mlb_boxscores_2025-08-24.csv
#   - Loaded 355 rows from mlb_boxscores_2025-08-25.csv
#   - Loaded 446 rows from mlb_boxscores_2025-08-26.csv
#   - Loaded 427 rows from mlb_boxscores_2025-08-27.csv
#   - Loaded 231 rows from mlb_boxscores_2025-08-28.csv
#   - Loaded 446 rows from mlb_boxscores_2025-08-29.csv
#   - Loaded 448 rows from mlb_boxscores_2025-08-30.csv
#   - Loaded 427 rows from mlb_boxscores_2025-08-31.csv
#   - Loaded 416 rows from mlb_boxscores_2025-09-01.csv
#   - Loaded 428 rows from mlb_boxscores_2025-09-02.csv
#   - Loaded 447 rows from mlb_boxscores_2025-09-03.csv
#   - Loaded 181 rows from mlb_boxscores_2025-09-04.csv
#   - Loaded 448 rows from mlb_boxscores_2025-09-05.csv
#   - Loaded 441 rows from mlb_boxscores_2025-09-06.csv
#   - Loaded 471 rows from mlb_boxscores_2025-09-07.csv
#   - Loaded 309 rows from mlb_boxscores_2025-09-08.csv
#   - Loaded 446 rows from mlb_boxscores_2025-09-09.csv
#   - Loaded 486 rows from mlb_boxscores_2025-09-10.csv
#   - Loaded 263 rows from mlb_boxscores_2025-09-11.csv
#   - Loaded 441 rows from mlb_boxscores_2025-09-12.csv
#   - Loaded 475 rows from mlb_boxscores_2025-09-13.csv
#   - Loaded 459 rows from mlb_boxscores_2025-09-14.csv
#   - Loaded 275 rows from mlb_boxscores_2025-09-15.csv
#   - Loaded 487 rows from mlb_boxscores_2025-09-16.csv
#   - Loaded 466 rows from mlb_boxscores_2025-09-17.csv
#   - Loaded 286 rows from mlb_boxscores_2025-09-18.csv
#   - Loaded 464 rows from mlb_boxscores_2025-09-19.csv
#   - Loaded 472 rows from mlb_boxscores_2025-09-20.csv
#   - Loaded 475 rows from mlb_boxscores_2025-09-21.csv
#   - Loaded 95 rows from mlb_boxscores_2025-09-22.csv
#   - Loaded 471 rows from mlb_boxscores_2025-09-23.csv
#   - Loaded 447 rows from mlb_boxscores_2025-09-24.csv
#   - Loaded 375 rows from mlb_boxscores_2025-09-25.csv
#   - Loaded 458 rows from mlb_boxscores_2025-09-26.csv
#   - Loaded 440 rows from mlb_boxscores_2025-09-27.csv
#   - Loaded 475 rows from mlb_boxscores_2025-09-28.csv
#   - Loaded 120 rows from mlb_boxscores_2025-09-30.csv
#
# Combined 186 files into data/csv/boxscores/combined_boxscores.csv
# Total rows: 151646
# Combined DataFrame shape: (151646, 18)
