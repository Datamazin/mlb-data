# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# %%
# Get yesterday’s date
yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')

# %%
# MLB API endpoint for daily schedule
url = f'https://statsapi.mlb.com/api/v1/schedule?sportId=1&date={yesterday}'
print(url)
# Out:
# https://statsapi.mlb.com/api/v1/schedule?sportId=1&date=2025-07-05

# %%
import json

response = requests.get(url)
data = response.json()
with open(f'assets/json/games/mlb_games_{yesterday}.json', 'w') as f:
    json.dump(data, f, indent=2)

# Extract games list
games = data.get('dates', [{}])[0].get('games', [])

if games:
    df = pd.json_normalize(games)
    # Filter games where status.detailedState is 'Final'
    df = df[df['status.detailedState'] == 'Final']
    df = df[['gamePk', 'gameDate', 'teams.away.team.id', 'teams.home.team.id']]
else:
    df = pd.DataFrame()
df.to_csv(f'assets/csv/games/mlb_games_{yesterday}.csv', index=False)

# %%
# Get list of gamePk values to fetch boxscores for each game
game_pks = df['gamePk'].tolist()
print(game_pks)
# Out:
# [777230, 777229, 777231, 777228, 777233, 777234, 777237, 777241, 777238, 777240, 777221, 777232, 777223, 777227, 777225]

# %%
# Iterate through game_pks to fetch boxscore data and append to boxscore.csv
for game_pk in game_pks:
    boxscore_url = f'https://statsapi.mlb.com/api/v1/game/{game_pk}/boxscore'
    boxscore_response = requests.get(boxscore_url)
    boxscore_data = boxscore_response.json()
    # Flatten the boxscore data for teams
    teams_data = boxscore_data.get('teams', {})
    for team_type in ['home', 'away']:
        team_info = teams_data.get(team_type, {})
        row = {
            'gamePk': game_pk,
            'team_type': team_type,
            'team_id': team_info.get('team', {}).get('id'),
            'team_name': team_info.get('team', {}).get('name'),
            'runs': team_info.get('teamStats', {}).get('batting', {}).get('runs'),
            'hits': team_info.get('teamStats', {}).get('batting', {}).get('hits'),
            'errors': team_info.get('teamStats', {}).get('fielding', {}).get('errors')
        }
        # Append to CSV
        pd.DataFrame([row]).to_csv('boxscore.csv', mode='a', header=not pd.io.common.file_exists('boxscore.csv'), index=False)

# %%
teams_data
# Out:
# {'away': {'team': {'springLeague': {'id': 115,
#     'name': 'Grapefruit League',
#     'link': '/api/v1/league/115',
#     'abbreviation': 'GL'},
#    'allStarStatus': 'N',
#    'id': 134,
#    'name': 'Pittsburgh Pirates',
#    'link': '/api/v1/teams/134',
#    'season': 2025,
#    'venue': {'id': 31, 'name': 'PNC Park', 'link': '/api/v1/venues/31'},
#    'springVenue': {'id': 2526, 'link': '/api/v1/venues/2526'},
#    'teamCode': 'pit',
#    'fileCode': 'pit',
#    'abbreviation': 'PIT',
#    'teamName': 'Pirates',
#    'locationName': 'Pittsburgh',
#    'firstYearOfPlay': '1882',
#    'league': {'id': 104,
#     'name': 'National League',
#     'link': '/api/v1/league/104'},
#    'division': {'id': 205,
#     'name': 'National League Central',
#     'link': '/api/v1/divisions/205'},
#    'sport': {'id': 1,
#     'link': '/api/v1/sports/1',
#     'name': 'Major League Baseball'},
#    'shortName': 'Pittsburgh',
#    'record': {'gamesPlayed': 90,
#     'wildCardGamesBack': '-',
#     'leagueGamesBack': '-',
#     'springLeagueGamesBack': '-',
#     'sportGamesBack': '-',
#     'divisionGamesBack': '-',
#     'conferenceGamesBack': '-',
#     'leagueRecord': {'wins': 38, 'losses': 52, 'ties': 0, 'pct': '.422'},
#     'records': {},
#     'divisionLeader': False,
#     'wins': 38,
#     'losses': 52,
#     'winningPercentage': '.422'},
#    'franchiseName': 'Pittsburgh',
#    'clubName': 'Pirates',
#    'active': True},
#   'teamStats': {'batting': {'flyOuts': 3,
#     'groundOuts': 10,
#     'airOuts': 6,
#     'runs': 0,
#     'doubles': 0,
#     'triples': 0,
#     'homeRuns': 0,
#     'strikeOuts': 11,
#     'baseOnBalls': 1,
#     'intentionalWalks': 0,
#     'hits': 2,
#     'hitByPitch': 0,
#     'avg': '.232',
#     'atBats': 29,
#     'obp': '.304',
#     'slg': '.343',
#     'ops': '.647',
#     'caughtStealing': 0,
#     'stolenBases': 0,
#     'stolenBasePercentage': '.---',
#     'groundIntoDoublePlay': 0,
#     'groundIntoTriplePlay': 0,
#     'plateAppearances': 30,
#     'totalBases': 2,
#     'rbi': 0,
#     'leftOnBase': 6,
#     'sacBunts': 0,
#     'sacFlies': 0,
#     'catchersInterference': 0,
#     'pickoffs': 0,
#     'atBatsPerHomeRun': '-.--',
#     'popOuts': 1,
#     'lineOuts': 2},
#    'pitching': {'flyOuts': 5,
#     'groundOuts': 9,
#     'airOuts': 6,
#     'runs': 1,
#     'doubles': 4,
#     'triples': 0,
#     'homeRuns': 0,
#     'strikeOuts': 9,
#     'baseOnBalls': 5,
#     'intentionalWalks': 1,
#     'hits': 5,
#     'hitByPitch': 1,
#     'atBats': 29,
#     'obp': '.314',
#     'caughtStealing': 0,
#     'stolenBases': 1,
#     'stolenBasePercentage': '1.000',
#     'numberOfPitches': 146,
#     'era': '3.64',
#     'inningsPitched': '8.0',
#     'saveOpportunities': 0,
#     'earnedRuns': 1,
#     'whip': '1.19',
#     'battersFaced': 35,
#     'outs': 24,
#     'completeGames': 0,
#     'shutouts': 0,
#     'pitchesThrown': 146,
#     'balls': 55,
#     'strikes': 91,
#     'strikePercentage': '.620',
#     'hitBatsmen': 1,
#     'balks': 0,
#     'wildPitches': 0,
#     'pickoffs': 0,
#     'groundOutsToAirouts': '1.50',
#     'rbi': 1,
#     'pitchesPerInning': '18.25',
#     'runsScoredPer9': '1.13',
#     'homeRunsPer9': '0.00',
#     'inheritedRunners': 0,
#     'inheritedRunnersScored': 0,
#     'catchersInterference': 0,
#     'sacBunts': 0,
#     'sacFlies': 0,
#     'passedBall': 0,
#     'popOuts': 1,
#     'lineOuts': 0},
#    'fielding': {'caughtStealing': 0,
#     'stolenBases': 1,
#     'stolenBasePercentage': '1.000',
#     'assists': 6,
#     'putOuts': 24,
#     'errors': 0,
#     'chances': 30,
#     'passedBall': 0,
#     'pickoffs': 0}},
#   'players': {'ID672744': {'person': {'id': 672744,
#      'fullName': 'Alexander Canario',
#      'link': '/api/v1/people/672744',
#      'boxscoreName': 'Canario'},
#     'jerseyNumber': '29',
#     'position': {'code': '7',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'LF'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 134,
#     'stats': {'batting': {}, 'pitching': {}, 'fielding': {}},
#     'seasonStats': {'batting': {'gamesPlayed': 51,
#       'flyOuts': 18,
#       'groundOuts': 31,
#       'airOuts': 32,
#       'runs': 18,
#       'doubles': 5,
#       'triples': 1,
#       'homeRuns': 3,
#       'strikeOuts': 49,
#       'baseOnBalls': 14,
#       'intentionalWalks': 0,
#       'hits': 32,
#       'hitByPitch': 0,
#       'avg': '.222',
#       'atBats': 144,
#       'obp': '.291',
#       'slg': '.333',
#       'ops': '.624',
#       'caughtStealing': 1,
#       'stolenBases': 2,
#       'stolenBasePercentage': '.667',
#       'groundIntoDoublePlay': 3,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 158,
#       'totalBases': 48,
#       'rbi': 12,
#       'leftOnBase': 76,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.315',
#       'groundOutsToAirouts': '0.97',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '48.00',
#       'popOuts': 6,
#       'lineOuts': 8},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 1,
#       'putOuts': 97,
#       'errors': 1,
#       'chances': 99,
#       'fielding': '.990',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': True,
#      'isSubstitute': False}},
#    'ID624428': {'person': {'id': 624428,
#      'fullName': 'Adam Frazier',
#      'link': '/api/v1/people/624428',
#      'boxscoreName': 'Frazier'},
#     'jerseyNumber': '26',
#     'position': {'code': '4',
#      'name': 'Second Base',
#      'type': 'Infielder',
#      'abbreviation': '2B'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 134,
#     'stats': {'batting': {}, 'pitching': {}, 'fielding': {}},
#     'seasonStats': {'batting': {'gamesPlayed': 74,
#       'flyOuts': 38,
#       'groundOuts': 64,
#       'airOuts': 68,
#       'runs': 22,
#       'doubles': 10,
#       'triples': 0,
#       'homeRuns': 3,
#       'strikeOuts': 44,
#       'baseOnBalls': 17,
#       'intentionalWalks': 2,
#       'hits': 59,
#       'hitByPitch': 6,
#       'avg': '.255',
#       'atBats': 231,
#       'obp': '.319',
#       'slg': '.338',
#       'ops': '.657',
#       'caughtStealing': 5,
#       'stolenBases': 7,
#       'stolenBasePercentage': '.583',
#       'groundIntoDoublePlay': 8,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 258,
#       'totalBases': 78,
#       'rbi': 21,
#       'leftOnBase': 75,
#       'sacBunts': 1,
#       'sacFlies': 3,
#       'babip': '.299',
#       'groundOutsToAirouts': '0.94',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '77.00',
#       'popOuts': 11,
#       'lineOuts': 19},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 122,
#       'putOuts': 108,
#       'errors': 2,
#       'chances': 232,
#       'fielding': '.991',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': True,
#      'isSubstitute': False}},
#    'ID694973': {'person': {'id': 694973,
#      'fullName': 'Paul Skenes',
#      'link': '/api/v1/people/694973',
#      'boxscoreName': 'Skenes'},
#     'jerseyNumber': '30',
#     'position': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 134,
#     'stats': {'batting': {}, 'pitching': {}, 'fielding': {}},
#     'seasonStats': {'batting': {'gamesPlayed': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {'gamesPlayed': 18,
#       'gamesStarted': 18,
#       'flyOuts': 54,
#       'groundOuts': 112,
#       'airOuts': 97,
#       'runs': 28,
#       'doubles': 21,
#       'triples': 1,
#       'homeRuns': 5,
#       'strikeOuts': 115,
#       'baseOnBalls': 30,
#       'intentionalWalks': 0,
#       'hits': 72,
#       'hitByPitch': 3,
#       'atBats': 396,
#       'obp': '.245',
#       'caughtStealing': 1,
#       'stolenBases': 1,
#       'stolenBasePercentage': '.500',
#       'numberOfPitches': 1745,
#       'era': '2.03',
#       'inningsPitched': '111.0',
#       'wins': 4,
#       'losses': 7,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 25,
#       'whip': '0.92',
#       'battersFaced': 429,
#       'outs': 333,
#       'gamesPitched': 18,
#       'completeGames': 1,
#       'shutouts': 0,
#       'pitchesThrown': 1745,
#       'balls': 619,
#       'strikes': 1126,
#       'strikePercentage': '.650',
#       'hitBatsmen': 3,
#       'balks': 0,
#       'wildPitches': 2,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '1.15',
#       'rbi': 0,
#       'winPercentage': '.364',
#       'pitchesPerInning': '15.72',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '3.83',
#       'strikeoutsPer9Inn': '9.32',
#       'walksPer9Inn': '2.43',
#       'hitsPer9Inn': '5.84',
#       'runsScoredPer9': '2.27',
#       'homeRunsPer9': '0.41',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 16,
#       'lineOuts': 27},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 6,
#       'putOuts': 6,
#       'errors': 2,
#       'chances': 14,
#       'fielding': '.857',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': True,
#      'isSubstitute': False}},
#    'ID687462': {'person': {'id': 687462,
#      'fullName': 'Spencer Horwitz',
#      'link': '/api/v1/people/687462',
#      'boxscoreName': 'Horwitz'},
#     'jerseyNumber': '2',
#     'position': {'code': '3',
#      'name': 'First Base',
#      'type': 'Infielder',
#      'abbreviation': '1B'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 134,
#     'battingOrder': '100',
#     'stats': {'batting': {'summary': '2-4 | K',
#       'gamesPlayed': 1,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 1,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 1,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 2,
#       'hitByPitch': 0,
#       'atBats': 4,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 4,
#       'totalBases': 2,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 1,
#       'lineOuts': 0},
#      'pitching': {},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 2,
#       'putOuts': 6,
#       'errors': 0,
#       'chances': 8,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 40,
#       'flyOuts': 22,
#       'groundOuts': 32,
#       'airOuts': 37,
#       'runs': 17,
#       'doubles': 10,
#       'triples': 0,
#       'homeRuns': 2,
#       'strikeOuts': 40,
#       'baseOnBalls': 12,
#       'intentionalWalks': 1,
#       'hits': 36,
#       'hitByPitch': 1,
#       'avg': '.250',
#       'atBats': 144,
#       'obp': '.310',
#       'slg': '.361',
#       'ops': '.671',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 4,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 158,
#       'totalBases': 52,
#       'rbi': 15,
#       'leftOnBase': 59,
#       'sacBunts': 0,
#       'sacFlies': 1,
#       'babip': '.330',
#       'groundOutsToAirouts': '0.86',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '72.00',
#       'popOuts': 6,
#       'lineOuts': 9},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 26,
#       'putOuts': 289,
#       'errors': 1,
#       'chances': 316,
#       'fielding': '.997',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '3',
#       'name': 'First Base',
#       'type': 'Infielder',
#       'abbreviation': '1B'}]},
#    'ID668804': {'person': {'id': 668804,
#      'fullName': 'Bryan Reynolds',
#      'link': '/api/v1/people/668804',
#      'boxscoreName': 'Reynolds, B'},
#     'jerseyNumber': '10',
#     'position': {'code': '9',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'RF'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 134,
#     'battingOrder': '300',
#     'stats': {'batting': {'summary': '0-4 | 2 K',
#       'gamesPlayed': 1,
#       'flyOuts': 1,
#       'groundOuts': 1,
#       'airOuts': 1,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 2,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 4,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 4,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 1,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 5,
#       'errors': 0,
#       'chances': 5,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 84,
#       'flyOuts': 44,
#       'groundOuts': 87,
#       'airOuts': 74,
#       'runs': 32,
#       'doubles': 16,
#       'triples': 2,
#       'homeRuns': 10,
#       'strikeOuts': 94,
#       'baseOnBalls': 30,
#       'intentionalWalks': 1,
#       'hits': 76,
#       'hitByPitch': 2,
#       'avg': '.232',
#       'atBats': 328,
#       'obp': '.298',
#       'slg': '.384',
#       'ops': '.682',
#       'caughtStealing': 2,
#       'stolenBases': 3,
#       'stolenBasePercentage': '.600',
#       'groundIntoDoublePlay': 11,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 363,
#       'totalBases': 126,
#       'rbi': 45,
#       'leftOnBase': 145,
#       'sacBunts': 0,
#       'sacFlies': 3,
#       'babip': '.291',
#       'groundOutsToAirouts': '1.18',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '32.80',
#       'popOuts': 1,
#       'lineOuts': 29},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 1,
#       'putOuts': 132,
#       'errors': 2,
#       'chances': 135,
#       'fielding': '.985',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': True,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '9',
#       'name': 'Outfielder',
#       'type': 'Outfielder',
#       'abbreviation': 'RF'}]},
#    'ID663698': {'person': {'id': 663698,
#      'fullName': 'Joey Bart',
#      'link': '/api/v1/people/663698',
#      'boxscoreName': 'Bart'},
#     'jerseyNumber': '14',
#     'position': {'code': '2',
#      'name': 'Catcher',
#      'type': 'Catcher',
#      'abbreviation': 'C'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 134,
#     'battingOrder': '800',
#     'stats': {'batting': {'summary': '0-3 | K',
#       'gamesPlayed': 1,
#       'flyOuts': 0,
#       'groundOuts': 1,
#       'airOuts': 1,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 1,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 3,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 3,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 1,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 1},
#      'pitching': {},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 1,
#       'stolenBasePercentage': '1.000',
#       'assists': 0,
#       'putOuts': 9,
#       'errors': 0,
#       'chances': 9,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 55,
#       'flyOuts': 24,
#       'groundOuts': 50,
#       'airOuts': 35,
#       'runs': 12,
#       'doubles': 5,
#       'triples': 1,
#       'homeRuns': 1,
#       'strikeOuts': 56,
#       'baseOnBalls': 25,
#       'intentionalWalks': 0,
#       'hits': 43,
#       'hitByPitch': 3,
#       'avg': '.234',
#       'atBats': 184,
#       'obp': '.335',
#       'slg': '.288',
#       'ops': '.623',
#       'caughtStealing': 0,
#       'stolenBases': 1,
#       'stolenBasePercentage': '1.000',
#       'groundIntoDoublePlay': 11,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 212,
#       'totalBases': 53,
#       'rbi': 14,
#       'leftOnBase': 90,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.331',
#       'groundOutsToAirouts': '1.43',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '184.00',
#       'popOuts': 2,
#       'lineOuts': 9},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 8,
#       'stolenBases': 31,
#       'stolenBasePercentage': '.795',
#       'assists': 12,
#       'putOuts': 332,
#       'errors': 1,
#       'chances': 345,
#       'fielding': '.997',
#       'passedBall': 4,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '2',
#       'name': 'Catcher',
#       'type': 'Catcher',
#       'abbreviation': 'C'}]},
#    'ID665833': {'person': {'id': 665833,
#      'fullName': 'Oneil Cruz',
#      'link': '/api/v1/people/665833',
#      'boxscoreName': 'Cruz, O'},
#     'jerseyNumber': '15',
#     'position': {'code': '8',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'CF'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 134,
#     'battingOrder': '500',
#     'stats': {'batting': {'summary': '0-3 | K',
#       'gamesPlayed': 1,
#       'flyOuts': 0,
#       'groundOuts': 2,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 1,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 3,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 3,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 0,
#       'errors': 0,
#       'chances': 0,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 79,
#       'flyOuts': 31,
#       'groundOuts': 64,
#       'airOuts': 56,
#       'runs': 47,
#       'doubles': 11,
#       'triples': 1,
#       'homeRuns': 15,
#       'strikeOuts': 111,
#       'baseOnBalls': 46,
#       'intentionalWalks': 4,
#       'hits': 59,
#       'hitByPitch': 3,
#       'avg': '.206',
#       'atBats': 287,
#       'obp': '.319',
#       'slg': '.408',
#       'ops': '.727',
#       'caughtStealing': 3,
#       'stolenBases': 28,
#       'stolenBasePercentage': '.903',
#       'groundIntoDoublePlay': 5,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 339,
#       'totalBases': 117,
#       'rbi': 35,
#       'leftOnBase': 129,
#       'sacBunts': 0,
#       'sacFlies': 3,
#       'babip': '.268',
#       'groundOutsToAirouts': '1.14',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '19.13',
#       'popOuts': 8,
#       'lineOuts': 17},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 2,
#       'putOuts': 181,
#       'errors': 7,
#       'chances': 190,
#       'fielding': '.963',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '8',
#       'name': 'Outfielder',
#       'type': 'Outfielder',
#       'abbreviation': 'CF'}]},
#    'ID663767': {'person': {'id': 663767,
#      'fullName': 'Chase Shugart',
#      'link': '/api/v1/people/663767',
#      'boxscoreName': 'Shugart'},
#     'jerseyNumber': '55',
#     'position': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 134,
#     'stats': {'batting': {}, 'pitching': {}, 'fielding': {}},
#     'seasonStats': {'batting': {'gamesPlayed': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {'gamesPlayed': 31,
#       'gamesStarted': 0,
#       'flyOuts': 23,
#       'groundOuts': 31,
#       'airOuts': 53,
#       'runs': 13,
#       'doubles': 6,
#       'triples': 0,
#       'homeRuns': 4,
#       'strikeOuts': 21,
#       'baseOnBalls': 15,
#       'intentionalWalks': 2,
#       'hits': 26,
#       'hitByPitch': 1,
#       'atBats': 129,
#       'obp': '.286',
#       'caughtStealing': 0,
#       'stolenBases': 2,
#       'stolenBasePercentage': '1.000',
#       'numberOfPitches': 555,
#       'era': '2.97',
#       'inningsPitched': '36.1',
#       'wins': 4,
#       'losses': 3,
#       'saves': 0,
#       'saveOpportunities': 2,
#       'holds': 4,
#       'blownSaves': 2,
#       'earnedRuns': 12,
#       'whip': '1.13',
#       'battersFaced': 147,
#       'outs': 109,
#       'gamesPitched': 31,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 555,
#       'balls': 220,
#       'strikes': 335,
#       'strikePercentage': '.600',
#       'hitBatsmen': 1,
#       'balks': 0,
#       'wildPitches': 2,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '0.58',
#       'rbi': 0,
#       'winPercentage': '.571',
#       'pitchesPerInning': '15.28',
#       'gamesFinished': 11,
#       'strikeoutWalkRatio': '1.40',
#       'strikeoutsPer9Inn': '5.20',
#       'walksPer9Inn': '3.72',
#       'hitsPer9Inn': '6.44',
#       'runsScoredPer9': '3.22',
#       'homeRunsPer9': '0.99',
#       'inheritedRunners': 22,
#       'inheritedRunnersScored': 3,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 2,
#       'passedBall': 0,
#       'popOuts': 12,
#       'lineOuts': 18},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 2,
#       'putOuts': 1,
#       'errors': 0,
#       'chances': 3,
#       'fielding': '1.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': True,
#      'isSubstitute': False}},
#    'ID663647': {'person': {'id': 663647,
#      'fullName': "Ke'Bryan Hayes",
#      'link': '/api/v1/people/663647',
#      'boxscoreName': 'Hayes'},
#     'jerseyNumber': '13',
#     'position': {'code': '5',
#      'name': 'Third Base',
#      'type': 'Infielder',
#      'abbreviation': '3B'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 134,
#     'battingOrder': '600',
#     'stats': {'batting': {'summary': '0-3 | 2 K',
#       'gamesPlayed': 1,
#       'flyOuts': 0,
#       'groundOuts': 1,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 2,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 3,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 3,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 1,
#       'putOuts': 1,
#       'errors': 0,
#       'chances': 2,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 82,
#       'flyOuts': 37,
#       'groundOuts': 84,
#       'airOuts': 80,
#       'runs': 29,
#       'doubles': 7,
#       'triples': 2,
#       'homeRuns': 2,
#       'strikeOuts': 66,
#       'baseOnBalls': 17,
#       'intentionalWalks': 0,
#       'hits': 74,
#       'hitByPitch': 4,
#       'avg': '.244',
#       'atBats': 303,
#       'obp': '.293',
#       'slg': '.300',
#       'ops': '.593',
#       'caughtStealing': 2,
#       'stolenBases': 10,
#       'stolenBasePercentage': '.833',
#       'groundIntoDoublePlay': 7,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 325,
#       'totalBases': 91,
#       'rbi': 29,
#       'leftOnBase': 135,
#       'sacBunts': 1,
#       'sacFlies': 0,
#       'babip': '.306',
#       'groundOutsToAirouts': '1.05',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '151.50',
#       'popOuts': 22,
#       'lineOuts': 21},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 177,
#       'putOuts': 53,
#       'errors': 4,
#       'chances': 234,
#       'fielding': '.983',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '5',
#       'name': 'Third Base',
#       'type': 'Infielder',
#       'abbreviation': '3B'}]},
#    'ID657571': {'person': {'id': 657571,
#      'fullName': 'Caleb Ferguson',
#      'link': '/api/v1/people/657571',
#      'boxscoreName': 'Ferguson, C'},
#     'jerseyNumber': '64',
#     'position': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 134,
#     'stats': {'batting': {},
#      'pitching': {'note': '(L, 2-1)',
#       'summary': '0.2 IP, ER, 0 K, BB',
#       'gamesPlayed': 1,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 2,
#       'airOuts': 0,
#       'runs': 1,
#       'doubles': 2,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 1,
#       'intentionalWalks': 0,
#       'hits': 2,
#       'hitByPitch': 1,
#       'atBats': 4,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 26,
#       'inningsPitched': '0.2',
#       'wins': 0,
#       'losses': 1,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 1,
#       'battersFaced': 6,
#       'outs': 2,
#       'gamesPitched': 1,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 26,
#       'balls': 13,
#       'strikes': 13,
#       'strikePercentage': '.500',
#       'hitBatsmen': 1,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'rbi': 1,
#       'gamesFinished': 0,
#       'runsScoredPer9': '13.50',
#       'homeRunsPer9': '0.00',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 0,
#       'errors': 0,
#       'chances': 0,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {'gamesPlayed': 39,
#       'gamesStarted': 0,
#       'flyOuts': 18,
#       'groundOuts': 45,
#       'airOuts': 35,
#       'runs': 12,
#       'doubles': 6,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 30,
#       'baseOnBalls': 14,
#       'intentionalWalks': 2,
#       'hits': 27,
#       'hitByPitch': 5,
#       'atBats': 134,
#       'obp': '.297',
#       'caughtStealing': 1,
#       'stolenBases': 6,
#       'stolenBasePercentage': '.857',
#       'numberOfPitches': 603,
#       'era': '2.79',
#       'inningsPitched': '38.2',
#       'wins': 2,
#       'losses': 1,
#       'saves': 0,
#       'saveOpportunities': 3,
#       'holds': 9,
#       'blownSaves': 3,
#       'earnedRuns': 12,
#       'whip': '1.06',
#       'battersFaced': 156,
#       'outs': 116,
#       'gamesPitched': 39,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 603,
#       'balls': 216,
#       'strikes': 387,
#       'strikePercentage': '.640',
#       'hitBatsmen': 5,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '1.29',
#       'rbi': 1,
#       'winPercentage': '.667',
#       'pitchesPerInning': '15.59',
#       'gamesFinished': 2,
#       'strikeoutWalkRatio': '2.14',
#       'strikeoutsPer9Inn': '6.98',
#       'walksPer9Inn': '3.26',
#       'hitsPer9Inn': '6.28',
#       'runsScoredPer9': '2.79',
#       'homeRunsPer9': '0.00',
#       'inheritedRunners': 17,
#       'inheritedRunnersScored': 5,
#       'catchersInterference': 0,
#       'sacBunts': 1,
#       'sacFlies': 2,
#       'passedBall': 0,
#       'popOuts': 6,
#       'lineOuts': 11},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 2,
#       'putOuts': 2,
#       'errors': 0,
#       'chances': 4,
#       'fielding': '1.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '1',
#       'name': 'Pitcher',
#       'type': 'Pitcher',
#       'abbreviation': 'P'}]},
#    'ID669707': {'person': {'id': 669707,
#      'fullName': 'Jared Triolo',
#      'link': '/api/v1/people/669707',
#      'boxscoreName': 'Triolo'},
#     'jerseyNumber': '19',
#     'position': {'code': '6',
#      'name': 'Shortstop',
#      'type': 'Infielder',
#      'abbreviation': 'SS'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 134,
#     'stats': {'batting': {}, 'pitching': {}, 'fielding': {}},
#     'seasonStats': {'batting': {'gamesPlayed': 51,
#       'flyOuts': 31,
#       'groundOuts': 35,
#       'airOuts': 50,
#       'runs': 12,
#       'doubles': 6,
#       'triples': 0,
#       'homeRuns': 3,
#       'strikeOuts': 28,
#       'baseOnBalls': 16,
#       'intentionalWalks': 1,
#       'hits': 22,
#       'hitByPitch': 1,
#       'avg': '.167',
#       'atBats': 132,
#       'obp': '.260',
#       'slg': '.280',
#       'ops': '.540',
#       'caughtStealing': 1,
#       'stolenBases': 5,
#       'stolenBasePercentage': '.833',
#       'groundIntoDoublePlay': 3,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 152,
#       'totalBases': 37,
#       'rbi': 10,
#       'leftOnBase': 65,
#       'sacBunts': 2,
#       'sacFlies': 1,
#       'babip': '.186',
#       'groundOutsToAirouts': '0.70',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '44.00',
#       'popOuts': 9,
#       'lineOuts': 10},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 86,
#       'putOuts': 136,
#       'errors': 4,
#       'chances': 226,
#       'fielding': '.982',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': True,
#      'isSubstitute': False}},
#    'ID656605': {'person': {'id': 656605,
#      'fullName': 'Mitch Keller',
#      'link': '/api/v1/people/656605',
#      'boxscoreName': 'Keller, M'},
#     'jerseyNumber': '23',
#     'position': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 134,
#     'stats': {'batting': {}, 'pitching': {}, 'fielding': {}},
#     'seasonStats': {'batting': {'gamesPlayed': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {'gamesPlayed': 18,
#       'gamesStarted': 18,
#       'flyOuts': 65,
#       'groundOuts': 113,
#       'airOuts': 116,
#       'runs': 47,
#       'doubles': 24,
#       'triples': 1,
# ...
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {'gamesPlayed': 40,
#       'gamesStarted': 0,
#       'flyOuts': 34,
#       'groundOuts': 32,
#       'airOuts': 60,
#       'runs': 14,
#       'doubles': 2,
#       'triples': 1,
#       'homeRuns': 5,
#       'strikeOuts': 42,
#       'baseOnBalls': 19,
#       'intentionalWalks': 1,
#       'hits': 31,
#       'hitByPitch': 1,
#       'atBats': 163,
#       'obp': '.276',
#       'caughtStealing': 0,
#       'stolenBases': 4,
#       'stolenBasePercentage': '1.000',
#       'numberOfPitches': 743,
#       'era': '2.72',
#       'inningsPitched': '46.1',
#       'wins': 3,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 1,
#       'holds': 1,
#       'blownSaves': 1,
#       'earnedRuns': 14,
#       'whip': '1.08',
#       'battersFaced': 185,
#       'outs': 139,
#       'gamesPitched': 40,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 743,
#       'balls': 270,
#       'strikes': 473,
#       'strikePercentage': '.640',
#       'hitBatsmen': 1,
#       'balks': 0,
#       'wildPitches': 1,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '0.53',
#       'rbi': 0,
#       'winPercentage': '1.000',
#       'pitchesPerInning': '16.04',
#       'gamesFinished': 14,
#       'strikeoutWalkRatio': '2.21',
#       'strikeoutsPer9Inn': '8.16',
#       'walksPer9Inn': '3.69',
#       'hitsPer9Inn': '6.02',
#       'runsScoredPer9': '2.72',
#       'homeRunsPer9': '0.97',
#       'inheritedRunners': 12,
#       'inheritedRunnersScored': 1,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 2,
#       'passedBall': 0,
#       'popOuts': 10,
#       'lineOuts': 16},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 3,
#       'putOuts': 0,
#       'errors': 0,
#       'chances': 3,
#       'fielding': '1.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': True,
#      'isSubstitute': False}},
#    'ID593871': {'person': {'id': 593871,
#      'fullName': 'Jorge Polanco',
#      'link': '/api/v1/people/593871',
#      'boxscoreName': 'Polanco'},
#     'jerseyNumber': '7',
#     'position': {'code': '10',
#      'name': 'Designated Hitter',
#      'type': 'Hitter',
#      'abbreviation': 'DH'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 136,
#     'battingOrder': '500',
#     'stats': {'batting': {'summary': '1-4 | 2B, K, R',
#       'gamesPlayed': 1,
#       'flyOuts': 1,
#       'groundOuts': 1,
#       'airOuts': 1,
#       'runs': 1,
#       'doubles': 1,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 1,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 1,
#       'hitByPitch': 0,
#       'atBats': 4,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 4,
#       'totalBases': 2,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 0,
#       'errors': 0,
#       'chances': 0,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 71,
#       'flyOuts': 36,
#       'groundOuts': 73,
#       'airOuts': 75,
#       'runs': 28,
#       'doubles': 12,
#       'triples': 0,
#       'homeRuns': 12,
#       'strikeOuts': 36,
#       'baseOnBalls': 17,
#       'intentionalWalks': 0,
#       'hits': 61,
#       'hitByPitch': 3,
#       'avg': '.253',
#       'atBats': 241,
#       'obp': '.307',
#       'slg': '.452',
#       'ops': '.759',
#       'caughtStealing': 2,
#       'stolenBases': 3,
#       'stolenBasePercentage': '.600',
#       'groundIntoDoublePlay': 5,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 265,
#       'totalBases': 109,
#       'rbi': 39,
#       'leftOnBase': 89,
#       'sacBunts': 1,
#       'sacFlies': 3,
#       'babip': '.250',
#       'groundOutsToAirouts': '0.97',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '20.08',
#       'popOuts': 22,
#       'lineOuts': 17},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 25,
#       'putOuts': 13,
#       'errors': 0,
#       'chances': 38,
#       'fielding': '1.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '10',
#       'name': 'Designated Hitter',
#       'type': 'Hitter',
#       'abbreviation': 'DH'}]},
#    'ID670042': {'person': {'id': 670042,
#      'fullName': 'Luke Raley',
#      'link': '/api/v1/people/670042',
#      'boxscoreName': 'Raley, L'},
#     'jerseyNumber': '20',
#     'position': {'code': '9',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'RF'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 136,
#     'battingOrder': '600',
#     'stats': {'batting': {'summary': '1-4 | K',
#       'gamesPlayed': 1,
#       'flyOuts': 0,
#       'groundOuts': 2,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 1,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 1,
#       'hitByPitch': 0,
#       'atBats': 4,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 4,
#       'totalBases': 1,
#       'rbi': 0,
#       'leftOnBase': 1,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 7,
#       'errors': 0,
#       'chances': 7,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 36,
#       'flyOuts': 12,
#       'groundOuts': 34,
#       'airOuts': 21,
#       'runs': 14,
#       'doubles': 6,
#       'triples': 0,
#       'homeRuns': 3,
#       'strikeOuts': 29,
#       'baseOnBalls': 12,
#       'intentionalWalks': 0,
#       'hits': 26,
#       'hitByPitch': 8,
#       'avg': '.241',
#       'atBats': 108,
#       'obp': '.357',
#       'slg': '.380',
#       'ops': '.737',
#       'caughtStealing': 1,
#       'stolenBases': 2,
#       'stolenBasePercentage': '.667',
#       'groundIntoDoublePlay': 1,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 130,
#       'totalBases': 41,
#       'rbi': 14,
#       'leftOnBase': 56,
#       'sacBunts': 1,
#       'sacFlies': 1,
#       'babip': '.299',
#       'groundOutsToAirouts': '1.62',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '36.00',
#       'popOuts': 5,
#       'lineOuts': 4},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 7,
#       'putOuts': 109,
#       'errors': 0,
#       'chances': 116,
#       'fielding': '1.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '3',
#       'name': 'First Base',
#       'type': 'Infielder',
#       'abbreviation': '1B'},
#      {'code': '9',
#       'name': 'Outfielder',
#       'type': 'Outfielder',
#       'abbreviation': 'RF'}]},
#    'ID672841': {'person': {'id': 672841,
#      'fullName': 'Carlos Vargas',
#      'link': '/api/v1/people/672841',
#      'boxscoreName': 'Vargas'},
#     'jerseyNumber': '54',
#     'position': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 136,
#     'stats': {'batting': {}, 'pitching': {}, 'fielding': {}},
#     'seasonStats': {'batting': {'gamesPlayed': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {'gamesPlayed': 40,
#       'gamesStarted': 0,
#       'flyOuts': 24,
#       'groundOuts': 49,
#       'airOuts': 42,
#       'runs': 19,
#       'doubles': 3,
#       'triples': 1,
#       'homeRuns': 5,
#       'strikeOuts': 32,
#       'baseOnBalls': 19,
#       'intentionalWalks': 4,
#       'hits': 42,
#       'hitByPitch': 1,
#       'atBats': 163,
#       'obp': '.337',
#       'caughtStealing': 1,
#       'stolenBases': 6,
#       'stolenBasePercentage': '.857',
#       'numberOfPitches': 627,
#       'era': '3.16',
#       'inningsPitched': '42.2',
#       'wins': 3,
#       'losses': 5,
#       'saves': 1,
#       'saveOpportunities': 6,
#       'holds': 10,
#       'blownSaves': 5,
#       'earnedRuns': 15,
#       'whip': '1.43',
#       'battersFaced': 185,
#       'outs': 128,
#       'gamesPitched': 40,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 627,
#       'balls': 229,
#       'strikes': 398,
#       'strikePercentage': '.630',
#       'hitBatsmen': 1,
#       'balks': 0,
#       'wildPitches': 1,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '1.17',
#       'rbi': 0,
#       'winPercentage': '.375',
#       'pitchesPerInning': '14.70',
#       'gamesFinished': 5,
#       'strikeoutWalkRatio': '1.68',
#       'strikeoutsPer9Inn': '6.75',
#       'walksPer9Inn': '4.01',
#       'hitsPer9Inn': '8.86',
#       'runsScoredPer9': '4.01',
#       'homeRunsPer9': '1.05',
#       'inheritedRunners': 9,
#       'inheritedRunnersScored': 5,
#       'catchersInterference': 0,
#       'sacBunts': 1,
#       'sacFlies': 1,
#       'passedBall': 0,
#       'popOuts': 6,
#       'lineOuts': 12},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 5,
#       'putOuts': 4,
#       'errors': 1,
#       'chances': 10,
#       'fielding': '.900',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': True,
#      'isSubstitute': False}}},
#   'batters': [641487,
#    677594,
#    663728,
#    668227,
#    593871,
#    670042,
#    686527,
#    456781,
#    810938,
#    702284,
#    622491,
#    666374,
#    662253],
#   'pitchers': [622491, 666374, 662253],
#   'bench': [641598, 670156, 664238],
#   'bullpen': [660825,
#    686228,
#    688138,
#    669302,
#    669923,
#    668984,
#    642100,
#    663423,
#    672841,
#    693433],
#   'battingOrder': [641487,
#    677594,
#    663728,
#    668227,
#    593871,
#    670042,
#    456781,
#    810938,
#    702284],
#   'info': [{'title': 'BATTING',
#     'fieldList': [{'label': '2B',
#       'value': 'Crawford, J (12, Burrows); Canzone (3, Burrows); Polanco (12, Ferguson, C); Williamson (11, Ferguson, C).'},
#      {'label': 'TB',
#       'value': 'Canzone 2; Crawford, J 2; Polanco 2; Raley, L; Williamson 2.'},
#      {'label': 'RBI', 'value': 'Williamson (15).'},
#      {'label': '2-out RBI', 'value': 'Williamson.'},
#      {'label': 'Runners left in scoring position, 2 out',
#       'value': 'Rodríguez, J 2; Williamson; Arozarena 2.'},
#      {'label': 'Team RISP', 'value': '1-for-8.'},
#      {'label': 'Team LOB', 'value': '10.'}]},
#    {'title': 'BASERUNNING',
#     'fieldList': [{'label': 'SB',
#       'value': 'Rodríguez, J (15, 3rd base off Burrows/Bart).'}]}],
#   'note': [{'label': 'a', 'value': 'Grounded out for Canzone in the 6th.'}]}}
