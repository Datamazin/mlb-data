# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# %%
# Get yesterday’s date
yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')

# %%
# MLB API endpoint for daily schedule
url = f'https://statsapi.mlb.com/api/v1/schedule?sportId=1&date={yesterday}'
print(url)
# Out:
# https://statsapi.mlb.com/api/v1/schedule?sportId=1&date=2025-07-19

# %%
import json
import os

response = requests.get(url)
data = response.json()

# Create directories relative to your current project root
os.makedirs('data/json/games', exist_ok=True)
with open(f'data/json/games/mlb_games_{yesterday}.json', 'w') as f:
    json.dump(data, f, indent=2)

# Extract games list
games = data.get('dates', [{}])[0].get('games', [])

if games:
    df = pd.json_normalize(games)
    # Filter games where status.detailedState is 'Final'
    df = df[df['status.detailedState'] == 'Final']
    df = df[['gamePk', 'gameDate', 'teams.away.team.id', 'teams.home.team.id']]
else:
    df = pd.DataFrame()

# Create CSV directory and save file
os.makedirs('data/csv/games', exist_ok=True)
df.to_csv(f'data/csv/games/mlb_games_{yesterday}.csv', index=False)
print(f"Created file: data/csv/games/mlb_games_{yesterday}.csv with {len(df)} games")
# Out:
# Created file: data/csv/games/mlb_games_2025-07-19.csv with 15 games

# %%
# Get list of gamePk values to fetch boxscores for each game
game_pks = df['gamePk'].tolist()
print(game_pks)
# Out:
# [777094, 777092, 777093, 777089, 777090, 777091, 777095, 777088, 777104, 777096, 777081, 777097, 777080, 777085, 777086]

# %%
# Iterate through game_pks to fetch boxscore data and append to boxscore.csv
for game_pk in game_pks:
    boxscore_url = f'https://statsapi.mlb.com/api/v1/game/{game_pk}/boxscore'
    boxscore_response = requests.get(boxscore_url)
    boxscore_data = boxscore_response.json()
    # Flatten the boxscore data for teams
    teams_data = boxscore_data.get('teams', {})
    for team_type in ['home', 'away']:
        team_info = teams_data.get(team_type, {})
        row = {
            'gamePk': game_pk,
            'team_type': team_type,
            'team_id': team_info.get('team', {}).get('id'),
            'team_name': team_info.get('team', {}).get('name'),
            'runs': team_info.get('teamStats', {}).get('batting', {}).get('runs'),
            'hits': team_info.get('teamStats', {}).get('batting', {}).get('hits'),
            'errors': team_info.get('teamStats', {}).get('fielding', {}).get('errors')
        }
        # Append to CSV
        pd.DataFrame([row]).to_csv('boxscore.csv', mode='a', header=not pd.io.common.file_exists('boxscore.csv'), index=False)

# %%
teams_data
# Out:
# {'away': {'team': {'springLeague': {'id': 115,
#     'name': 'Grapefruit League',
#     'link': '/api/v1/league/115',
#     'abbreviation': 'GL'},
#    'allStarStatus': 'N',
#    'id': 117,
#    'name': 'Houston Astros',
#    'link': '/api/v1/teams/117',
#    'season': 2025,
#    'venue': {'id': 2392, 'name': 'Daikin Park', 'link': '/api/v1/venues/2392'},
#    'springVenue': {'id': 5000, 'link': '/api/v1/venues/5000'},
#    'teamCode': 'hou',
#    'fileCode': 'hou',
#    'abbreviation': 'HOU',
#    'teamName': 'Astros',
#    'locationName': 'Houston',
#    'firstYearOfPlay': '1962',
#    'league': {'id': 103,
#     'name': 'American League',
#     'link': '/api/v1/league/103'},
#    'division': {'id': 200,
#     'name': 'American League West',
#     'link': '/api/v1/divisions/200'},
#    'sport': {'id': 1,
#     'link': '/api/v1/sports/1',
#     'name': 'Major League Baseball'},
#    'shortName': 'Houston',
#    'record': {'gamesPlayed': 98,
#     'wildCardGamesBack': '-',
#     'leagueGamesBack': '-',
#     'springLeagueGamesBack': '-',
#     'sportGamesBack': '-',
#     'divisionGamesBack': '-',
#     'conferenceGamesBack': '-',
#     'leagueRecord': {'wins': 56, 'losses': 42, 'ties': 0, 'pct': '.571'},
#     'records': {},
#     'divisionLeader': False,
#     'wins': 56,
#     'losses': 42,
#     'winningPercentage': '.571'},
#    'franchiseName': 'Houston',
#    'clubName': 'Astros',
#    'active': True},
#   'teamStats': {'batting': {'flyOuts': 5,
#     'groundOuts': 7,
#     'airOuts': 11,
#     'runs': 6,
#     'doubles': 1,
#     'triples': 0,
#     'homeRuns': 0,
#     'strikeOuts': 14,
#     'baseOnBalls': 6,
#     'intentionalWalks': 1,
#     'hits': 12,
#     'hitByPitch': 2,
#     'avg': '.258',
#     'atBats': 42,
#     'obp': '.323',
#     'slg': '.407',
#     'ops': '.730',
#     'caughtStealing': 0,
#     'stolenBases': 2,
#     'stolenBasePercentage': '1.000',
#     'groundIntoDoublePlay': 1,
#     'groundIntoTriplePlay': 0,
#     'plateAppearances': 52,
#     'totalBases': 13,
#     'rbi': 6,
#     'leftOnBase': 28,
#     'sacBunts': 1,
#     'sacFlies': 1,
#     'catchersInterference': 0,
#     'pickoffs': 0,
#     'atBatsPerHomeRun': '-.--',
#     'popOuts': 2,
#     'lineOuts': 4},
#    'pitching': {'flyOuts': 7,
#     'groundOuts': 10,
#     'airOuts': 11,
#     'runs': 7,
#     'doubles': 2,
#     'triples': 0,
#     'homeRuns': 0,
#     'strikeOuts': 9,
#     'baseOnBalls': 6,
#     'intentionalWalks': 0,
#     'hits': 7,
#     'hitByPitch': 2,
#     'atBats': 35,
#     'obp': '.349',
#     'caughtStealing': 0,
#     'stolenBases': 1,
#     'stolenBasePercentage': '1.000',
#     'numberOfPitches': 202,
#     'era': '3.64',
#     'inningsPitched': '10.1',
#     'saveOpportunities': 0,
#     'earnedRuns': 5,
#     'whip': '1.17',
#     'battersFaced': 45,
#     'outs': 31,
#     'completeGames': 0,
#     'shutouts': 0,
#     'pitchesThrown': 202,
#     'balls': 82,
#     'strikes': 120,
#     'strikePercentage': '.590',
#     'hitBatsmen': 2,
#     'balks': 0,
#     'wildPitches': 1,
#     'pickoffs': 0,
#     'groundOutsToAirouts': '0.91',
#     'rbi': 6,
#     'pitchesPerInning': '19.55',
#     'runsScoredPer9': '6.10',
#     'homeRunsPer9': '0.00',
#     'inheritedRunners': 0,
#     'inheritedRunnersScored': 0,
#     'catchersInterference': 0,
#     'sacBunts': 2,
#     'sacFlies': 0,
#     'passedBall': 0,
#     'popOuts': 2,
#     'lineOuts': 2},
#    'fielding': {'caughtStealing': 0,
#     'stolenBases': 1,
#     'stolenBasePercentage': '1.000',
#     'assists': 12,
#     'putOuts': 31,
#     'errors': 1,
#     'chances': 44,
#     'passedBall': 0,
#     'pickoffs': 0}},
#   'players': {'ID664285': {'person': {'id': 664285,
#      'fullName': 'Framber Valdez',
#      'link': '/api/v1/people/664285',
#      'boxscoreName': 'Valdez, F'},
#     'jerseyNumber': '59',
#     'position': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 117,
#     'stats': {'batting': {}, 'pitching': {}, 'fielding': {}},
#     'seasonStats': {'batting': {'gamesPlayed': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {'gamesPlayed': 19,
#       'gamesStarted': 19,
#       'flyOuts': 42,
#       'groundOuts': 151,
#       'airOuts': 74,
#       'runs': 38,
#       'doubles': 21,
#       'triples': 3,
#       'homeRuns': 8,
#       'strikeOuts': 125,
#       'baseOnBalls': 41,
#       'intentionalWalks': 0,
#       'hits': 95,
#       'hitByPitch': 5,
#       'atBats': 442,
#       'obp': '.288',
#       'caughtStealing': 2,
#       'stolenBases': 17,
#       'stolenBasePercentage': '.895',
#       'numberOfPitches': 1774,
#       'era': '2.75',
#       'inningsPitched': '121.0',
#       'wins': 10,
#       'losses': 4,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 37,
#       'whip': '1.12',
#       'battersFaced': 491,
#       'outs': 363,
#       'gamesPitched': 19,
#       'completeGames': 2,
#       'shutouts': 0,
#       'pitchesThrown': 1774,
#       'balls': 624,
#       'strikes': 1150,
#       'strikePercentage': '.650',
#       'hitBatsmen': 5,
#       'balks': 0,
#       'wildPitches': 6,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '2.04',
#       'rbi': 0,
#       'winPercentage': '.714',
#       'pitchesPerInning': '14.66',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '3.05',
#       'strikeoutsPer9Inn': '9.30',
#       'walksPer9Inn': '3.05',
#       'hitsPer9Inn': '7.07',
#       'runsScoredPer9': '2.83',
#       'homeRunsPer9': '0.60',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 1,
#       'sacFlies': 2,
#       'passedBall': 0,
#       'popOuts': 7,
#       'lineOuts': 25},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 8,
#       'putOuts': 2,
#       'errors': 0,
#       'chances': 10,
#       'fielding': '1.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': True,
#      'isSubstitute': False}},
#    'ID670623': {'person': {'id': 670623,
#      'fullName': 'Isaac Paredes',
#      'link': '/api/v1/people/670623',
#      'boxscoreName': 'Paredes'},
#     'jerseyNumber': '15',
#     'position': {'code': '5',
#      'name': 'Third Base',
#      'type': 'Infielder',
#      'abbreviation': '3B'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 117,
#     'battingOrder': '100',
#     'stats': {'batting': {'summary': '1-2',
#       'gamesPlayed': 1,
#       'flyOuts': 0,
#       'groundOuts': 1,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 1,
#       'hitByPitch': 0,
#       'atBats': 2,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 2,
#       'totalBases': 1,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 0,
#       'errors': 0,
#       'chances': 0,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 94,
#       'flyOuts': 59,
#       'groundOuts': 69,
#       'airOuts': 126,
#       'runs': 51,
#       'doubles': 15,
#       'triples': 1,
#       'homeRuns': 19,
#       'strikeOuts': 67,
#       'baseOnBalls': 49,
#       'intentionalWalks': 0,
#       'hits': 91,
#       'hitByPitch': 7,
#       'avg': '.259',
#       'atBats': 351,
#       'obp': '.359',
#       'slg': '.470',
#       'ops': '.829',
#       'caughtStealing': 1,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.000',
#       'groundIntoDoublePlay': 8,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 409,
#       'totalBases': 165,
#       'rbi': 50,
#       'leftOnBase': 145,
#       'sacBunts': 0,
#       'sacFlies': 2,
#       'babip': '.270',
#       'groundOutsToAirouts': '0.55',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '18.47',
#       'popOuts': 31,
#       'lineOuts': 36},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 148,
#       'putOuts': 50,
#       'errors': 5,
#       'chances': 203,
#       'fielding': '.975',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '5',
#       'name': 'Third Base',
#       'type': 'Infielder',
#       'abbreviation': '3B'}]},
#    'ID650556': {'person': {'id': 650556,
#      'fullName': 'Bryan Abreu',
#      'link': '/api/v1/people/650556',
#      'boxscoreName': 'Abreu, B'},
#     'jerseyNumber': '52',
#     'position': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 117,
#     'stats': {'batting': {},
#      'pitching': {'note': '(BS, 4)',
#       'summary': '1.0 IP, ER, 2 K, 0 BB',
#       'gamesPlayed': 1,
#       'gamesStarted': 0,
#       'flyOuts': 1,
#       'groundOuts': 0,
#       'airOuts': 1,
#       'runs': 1,
#       'doubles': 1,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 2,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 1,
#       'hitByPitch': 1,
#       'atBats': 4,
#       'caughtStealing': 0,
#       'stolenBases': 1,
#       'stolenBasePercentage': '1.000',
#       'numberOfPitches': 17,
#       'inningsPitched': '1.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 1,
#       'holds': 0,
#       'blownSaves': 1,
#       'earnedRuns': 1,
#       'battersFaced': 5,
#       'outs': 3,
#       'gamesPitched': 1,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 17,
#       'balls': 5,
#       'strikes': 12,
#       'strikePercentage': '.710',
#       'hitBatsmen': 1,
#       'balks': 0,
#       'wildPitches': 1,
#       'pickoffs': 0,
#       'rbi': 0,
#       'gamesFinished': 0,
#       'runsScoredPer9': '9.00',
#       'homeRunsPer9': '0.00',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 0,
#       'errors': 0,
#       'chances': 0,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 1,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {'gamesPlayed': 43,
#       'gamesStarted': 0,
#       'flyOuts': 12,
#       'groundOuts': 23,
#       'airOuts': 38,
#       'runs': 9,
#       'doubles': 6,
#       'triples': 0,
#       'homeRuns': 3,
#       'strikeOuts': 68,
#       'baseOnBalls': 20,
#       'intentionalWalks': 0,
#       'hits': 27,
#       'hitByPitch': 3,
#       'atBats': 156,
#       'obp': '.279',
#       'caughtStealing': 1,
#       'stolenBases': 9,
#       'stolenBasePercentage': '.900',
#       'numberOfPitches': 722,
#       'era': '1.87',
#       'inningsPitched': '43.1',
#       'wins': 3,
#       'losses': 3,
#       'saves': 0,
#       'saveOpportunities': 4,
#       'holds': 23,
#       'blownSaves': 4,
#       'earnedRuns': 9,
#       'whip': '1.08',
#       'battersFaced': 179,
#       'outs': 130,
#       'gamesPitched': 43,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 722,
#       'balls': 278,
#       'strikes': 444,
#       'strikePercentage': '.610',
#       'hitBatsmen': 3,
#       'balks': 0,
#       'wildPitches': 3,
#       'pickoffs': 1,
#       'groundOutsToAirouts': '0.61',
#       'rbi': 0,
#       'winPercentage': '.500',
#       'pitchesPerInning': '16.66',
#       'gamesFinished': 7,
#       'strikeoutWalkRatio': '3.40',
#       'strikeoutsPer9Inn': '14.12',
#       'walksPer9Inn': '4.15',
#       'hitsPer9Inn': '5.61',
#       'runsScoredPer9': '1.87',
#       'homeRunsPer9': '0.62',
#       'inheritedRunners': 14,
#       'inheritedRunnersScored': 3,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 7,
#       'lineOuts': 19},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 3,
#       'putOuts': 1,
#       'errors': 1,
#       'chances': 5,
#       'fielding': '.800',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '1',
#       'name': 'Pitcher',
#       'type': 'Pitcher',
#       'abbreviation': 'P'}]},
#    'ID669450': {'person': {'id': 669450,
#      'fullName': 'Cooper Hummel',
#      'link': '/api/v1/people/669450',
#      'boxscoreName': 'Hummel'},
#     'jerseyNumber': '16',
#     'position': {'code': '7',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'LF'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 117,
#     'battingOrder': '701',
#     'stats': {'batting': {'note': 'b-',
#       'summary': '0-1 | K',
#       'gamesPlayed': 1,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 1,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 1,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 1,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 0,
#       'errors': 0,
#       'chances': 0,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 27,
#       'flyOuts': 8,
#       'groundOuts': 15,
#       'airOuts': 11,
#       'runs': 8,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 2,
#       'strikeOuts': 26,
#       'baseOnBalls': 12,
#       'intentionalWalks': 0,
#       'hits': 11,
#       'hitByPitch': 2,
#       'avg': '.177',
#       'atBats': 62,
#       'obp': '.329',
#       'slg': '.274',
#       'ops': '.603',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 77,
#       'totalBases': 17,
#       'rbi': 4,
#       'leftOnBase': 28,
#       'sacBunts': 1,
#       'sacFlies': 0,
#       'babip': '.265',
#       'groundOutsToAirouts': '1.36',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '31.00',
#       'popOuts': 2,
#       'lineOuts': 1},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 1,
#       'putOuts': 14,
#       'errors': 0,
#       'chances': 15,
#       'fielding': '1.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': True},
#     'allPositions': [{'code': '11',
#       'name': 'Pinch Hitter',
#       'type': 'Hitter',
#       'abbreviation': 'PH'},
#      {'code': '7',
#       'name': 'Outfielder',
#       'type': 'Outfielder',
#       'abbreviation': 'LF'}]},
#    'ID593576': {'person': {'id': 593576,
#      'fullName': 'Héctor Neris',
#      'link': '/api/v1/people/593576',
#      'boxscoreName': 'Neris'},
#     'jerseyNumber': '50',
#     'position': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 117,
#     'stats': {'batting': {},
#      'pitching': {'note': '(L, 3-2)',
#       'summary': '0.1 IP, 0 ER, 0 K, 0 BB',
#       'gamesPlayed': 1,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 1,
#       'airOuts': 0,
#       'runs': 1,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 1,
#       'hitByPitch': 0,
#       'atBats': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 8,
#       'inningsPitched': '0.1',
#       'wins': 0,
#       'losses': 1,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'battersFaced': 2,
#       'outs': 1,
#       'gamesPitched': 1,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 8,
#       'balls': 3,
#       'strikes': 5,
#       'strikePercentage': '.630',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'rbi': 1,
#       'gamesFinished': 1,
#       'runsScoredPer9': '27.00',
#       'homeRunsPer9': '0.00',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 1,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 0,
#       'errors': 0,
#       'chances': 0,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {'gamesPlayed': 28,
#       'gamesStarted': 0,
#       'flyOuts': 13,
#       'groundOuts': 10,
#       'airOuts': 20,
#       'runs': 17,
#       'doubles': 5,
#       'triples': 0,
#       'homeRuns': 3,
#       'strikeOuts': 25,
#       'baseOnBalls': 11,
#       'intentionalWalks': 1,
#       'hits': 19,
#       'hitByPitch': 1,
#       'atBats': 71,
#       'obp': '.369',
#       'caughtStealing': 0,
#       'stolenBases': 5,
#       'stolenBasePercentage': '1.000',
#       'numberOfPitches': 387,
#       'era': '7.11',
#       'inningsPitched': '19.0',
#       'wins': 3,
#       'losses': 2,
#       'saves': 0,
#       'saveOpportunities': 2,
#       'holds': 7,
#       'blownSaves': 2,
#       'earnedRuns': 15,
#       'whip': '1.58',
#       'battersFaced': 86,
#       'outs': 57,
#       'gamesPitched': 28,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 387,
#       'balls': 149,
#       'strikes': 238,
#       'strikePercentage': '.610',
#       'hitBatsmen': 1,
#       'balks': 0,
#       'wildPitches': 4,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '0.50',
#       'rbi': 1,
#       'winPercentage': '.600',
#       'pitchesPerInning': '20.37',
#       'gamesFinished': 6,
#       'strikeoutWalkRatio': '2.27',
#       'strikeoutsPer9Inn': '11.84',
#       'walksPer9Inn': '5.21',
#       'hitsPer9Inn': '9.00',
#       'runsScoredPer9': '8.05',
#       'homeRunsPer9': '1.42',
#       'inheritedRunners': 13,
#       'inheritedRunnersScored': 3,
#       'catchersInterference': 0,
#       'sacBunts': 2,
#       'sacFlies': 1,
#       'passedBall': 0,
#       'popOuts': 5,
#       'lineOuts': 2},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 1,
#       'putOuts': 0,
#       'errors': 0,
#       'chances': 1,
#       'fielding': '1.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': True,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '1',
#       'name': 'Pitcher',
#       'type': 'Pitcher',
#       'abbreviation': 'P'}]},
#    'ID605170': {'person': {'id': 605170,
#      'fullName': 'Victor Caratini',
#      'link': '/api/v1/people/605170',
#      'boxscoreName': 'Caratini'},
#     'jerseyNumber': '17',
#     'position': {'code': '2',
#      'name': 'Catcher',
#      'type': 'Catcher',
#      'abbreviation': 'C'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 117,
#     'battingOrder': '300',
#     'stats': {'batting': {'summary': '3-4 | 2 BB, K, RBI',
#       'gamesPlayed': 1,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 1,
#       'baseOnBalls': 2,
#       'intentionalWalks': 0,
#       'hits': 3,
#       'hitByPitch': 0,
#       'atBats': 4,
#       'caughtStealing': 0,
#       'stolenBases': 1,
#       'stolenBasePercentage': '1.000',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 6,
#       'totalBases': 3,
#       'rbi': 1,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 1,
#       'stolenBasePercentage': '1.000',
#       'assists': 0,
#       'putOuts': 10,
#       'errors': 0,
#       'chances': 10,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 68,
#       'flyOuts': 46,
#       'groundOuts': 54,
#       'airOuts': 73,
#       'runs': 24,
#       'doubles': 9,
#       'triples': 0,
#       'homeRuns': 10,
#       'strikeOuts': 42,
#       'baseOnBalls': 13,
#       'intentionalWalks': 0,
#       'hits': 59,
#       'hitByPitch': 6,
#       'avg': '.265',
#       'atBats': 223,
#       'obp': '.316',
#       'slg': '.439',
#       'ops': '.755',
#       'caughtStealing': 0,
#       'stolenBases': 1,
#       'stolenBasePercentage': '1.000',
#       'groundIntoDoublePlay': 7,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 247,
#       'totalBases': 98,
#       'rbi': 33,
#       'leftOnBase': 82,
#       'sacBunts': 0,
#       'sacFlies': 5,
#       'babip': '.278',
#       'groundOutsToAirouts': '0.74',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '22.30',
#       'popOuts': 15,
#       'lineOuts': 12},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 5,
#       'stolenBases': 41,
#       'stolenBasePercentage': '.891',
#       'assists': 14,
#       'putOuts': 340,
#       'errors': 4,
#       'chances': 358,
#       'fielding': '.989',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '2',
#       'name': 'Catcher',
#       'type': 'Catcher',
#       'abbreviation': 'C'}]},
#    'ID701358': {'person': {'id': 701358,
#      'fullName': 'Cam Smith',
#      'link': '/api/v1/people/701358',
#      'boxscoreName': 'Smith'},
#     'jerseyNumber': '11',
#     'position': {'code': '9',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'RF'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 117,
#     'battingOrder': '400',
#     'stats': {'batting': {'summary': '1-6 | 2 K, RBI',
#       'gamesPlayed': 1,
#       'flyOuts': 1,
#       'groundOuts': 1,
#       'airOuts': 2,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 2,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 1,
#       'hitByPitch': 0,
#       'atBats': 6,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 1,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 6,
#       'totalBases': 1,
#       'rbi': 1,
#       'leftOnBase': 9,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 1},
#      'pitching': {},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 4,
#       'errors': 0,
#       'chances': 4,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 84,
#       'flyOuts': 30,
#       'groundOuts': 71,
#       'airOuts': 57,
#       'runs': 39,
#       'doubles': 16,
#       'triples': 2,
#       'homeRuns': 7,
#       'strikeOuts': 92,
#       'baseOnBalls': 27,
#       'intentionalWalks': 0,
#       'hits': 82,
#       'hitByPitch': 4,
#       'avg': '.272',
#       'atBats': 302,
#       'obp': '.339',
#       'slg': '.407',
#       'ops': '.746',
#       'caughtStealing': 1,
#       'stolenBases': 5,
#       'stolenBasePercentage': '.833',
#       'groundIntoDoublePlay': 9,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 333,
#       'totalBases': 123,
#       'rbi': 40,
#       'leftOnBase': 130,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.369',
#       'groundOutsToAirouts': '1.25',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '43.14',
#       'popOuts': 6,
#       'lineOuts': 21},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 4,
#       'putOuts': 177,
#       'errors': 2,
#       'chances': 183,
#       'fielding': '.989',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '9',
#       'name': 'Outfielder',
#       'type': 'Outfielder',
#       'abbreviation': 'RF'}]},
#    'ID687888': {'person': {'id': 687888,
#      'fullName': 'Brandon Walter',
#      'link': '/api/v1/people/687888',
#      'boxscoreName': 'Walter'},
#     'jerseyNumber': '60',
#     'position': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 117,
#     'stats': {'batting': {}, 'pitching': {}, 'fielding': {}},
#     'seasonStats': {'batting': {'gamesPlayed': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {'gamesPlayed': 8,
#       'gamesStarted': 8,
#       'flyOuts': 24,
#       'groundOuts': 49,
#       'airOuts': 42,
#       'runs': 19,
#       'doubles': 7,
#       'triples': 1,
#       'homeRuns': 9,
#       'strikeOuts': 47,
#       'baseOnBalls': 3,
#       'intentionalWalks': 0,
#       'hits': 42,
#       'hitByPitch': 3,
#       'atBats': 179,
#       'obp': '.259',
#       'caughtStealing': 1,
#       'stolenBases': 3,
#       'stolenBasePercentage': '.750',
#       'numberOfPitches': 732,
#       'era': '3.66',
#       'inningsPitched': '46.2',
#       'wins': 1,
#       'losses': 3,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 19,
#       'whip': '0.96',
#       'battersFaced': 186,
#       'outs': 140,
#       'gamesPitched': 8,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 732,
#       'balls': 238,
#       'strikes': 494,
#       'strikePercentage': '.670',
#       'hitBatsmen': 3,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 1,
#       'groundOutsToAirouts': '1.17',
#       'rbi': 0,
#       'winPercentage': '.250',
#       'pitchesPerInning': '15.69',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '15.67',
#       'strikeoutsPer9Inn': '9.06',
#       'walksPer9Inn': '0.58',
#       'hitsPer9Inn': '8.10',
#       'runsScoredPer9': '3.66',
#       'homeRunsPer9': '1.74',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 1,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 8,
#       'lineOuts': 10},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 5,
#       'putOuts': 3,
#       'errors': 0,
#       'chances': 8,
#       'fielding': '1.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': True,
#      'isSubstitute': False}},
#    'ID643289': {'person': {'id': 643289,
#      'fullName': 'Mauricio Dubón',
#      'link': '/api/v1/people/643289',
#      'boxscoreName': 'Dubón'},
#     'jerseyNumber': '14',
#     'position': {'code': '6',
#      'name': 'Shortstop',
#      'type': 'Infielder',
#      'abbreviation': 'SS'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 117,
#     'battingOrder': '800',
#     'stats': {'batting': {'summary': '1-4 | BB, 2 K',
#       'gamesPlayed': 1,
#       'flyOuts': 0,
#       'groundOuts': 1,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 2,
#       'baseOnBalls': 1,
#       'intentionalWalks': 0,
#       'hits': 1,
#       'hitByPitch': 0,
#       'atBats': 4,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 5,
#       'totalBases': 1,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 3,
#       'putOuts': 1,
#       'errors': 0,
#       'chances': 4,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 74,
#       'flyOuts': 40,
#       'groundOuts': 61,
#       'airOuts': 74,
#       'runs': 26,
#       'doubles': 14,
#       'triples': 0,
#       'homeRuns': 6,
#       'strikeOuts': 22,
#       'baseOnBalls': 12,
#       'intentionalWalks': 0,
#       'hits': 53,
#       'hitByPitch': 0,
#       'avg': '.256',
#       'atBats': 207,
#       'obp': '.295',
#       'slg': '.411',
#       'ops': '.706',
#       'caughtStealing': 0,
#       'stolenBases': 2,
#       'stolenBasePercentage': '1.000',
#       'groundIntoDoublePlay': 7,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 222,
#       'totalBases': 85,
#       'rbi': 20,
#       'leftOnBase': 106,
#       'sacBunts': 2,
#       'sacFlies': 1,
#       'babip': '.261',
#       'groundOutsToAirouts': '0.82',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '34.50',
#       'popOuts': 18,
#       'lineOuts': 16},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 118,
#       'putOuts': 90,
#       'errors': 4,
#       'chances': 212,
#       'fielding': '.981',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '6',
#       'name': 'Shortstop',
#       'type': 'Infielder',
#       'abbreviation': 'SS'},
#      {'code': '5',
#       'name': 'Third Base',
#       'type': 'Infielder',
#       'abbreviation': '3B'},
#      {'code': '6',
#       'name': 'Shortstop',
#       'type': 'Infielder',
#       'abbreviation': 'SS'}]},
#    'ID686613': {'person': {'id': 686613,
#      'fullName': 'Hunter Brown',
#      'link': '/api/v1/people/686613',
#      'boxscoreName': 'Brown, H'},
#     'jerseyNumber': '58',
#     'position': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 117,
#     'stats': {'batting': {}, 'pitching': {}, 'fielding': {}},
#     'seasonStats': {'batting': {'gamesPlayed': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {'gamesPlayed': 19,
#       'gamesStarted': 19,
#       'flyOuts': 48,
#       'groundOuts': 104,
#       'airOuts': 87,
#       'runs': 32,
#       'doubles': 11,
#       'triples': 2,
#       'homeRuns': 12,
#       'strikeOuts': 137,
#       'baseOnBalls': 34,
#       'intentionalWalks': 1,
#       'hits': 76,
#       'hitByPitch': 3,
#       'atBats': 403,
#       'obp': '.256',
#       'caughtStealing': 5,
#       'stolenBases': 14,
#       'stolenBasePercentage': '.737',
#       'numberOfPitches': 1808,
#       'era': '2.43',
#       'inningsPitched': '115.0',
#       'wins': 9,
#       'losses': 4,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 31,
#       'whip': '0.96',
#       'battersFaced': 441,
#       'outs': 345,
#       'gamesPitched': 19,
#       'completeGames': 1,
#       'shutouts': 0,
#       'pitchesThrown': 1808,
#       'balls': 685,
#       'strikes': 1123,
#       'strikePercentage': '.620',
#       'hitBatsmen': 3,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 1,
#       'groundOutsToAirouts': '1.20',
#       'rbi': 0,
#       'winPercentage': '.692',
#       'pitchesPerInning': '15.72',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '4.03',
#       'strikeoutsPer9Inn': '10.72',
#       'walksPer9Inn': '2.66',
#       'hitsPer9Inn': '5.95',
#       'runsScoredPer9': '2.50',
#       'homeRunsPer9': '0.94',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 1,
#       'passedBall': 0,
#       'popOuts': 18,
#       'lineOuts': 21},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 10,
#       'putOuts': 7,
#       'errors': 0,
#       'chances': 17,
#       'fielding': '1.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': True,
#      'isSubstitute': False}},
#    'ID623352': {'person': {'id': 623352,
#      'fullName': 'Josh Hader',
#      'link': '/api/v1/people/623352',
#      'boxscoreName': 'Hader'},
#     'jerseyNumber': '71',
#     'position': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 117,
#     'stats': {'batting': {},
#      'pitching': {'summary': '2.0 IP, 0 ER, K, 2 BB',
#       'gamesPlayed': 1,
#       'gamesStarted': 0,
#       'flyOuts': 1,
#       'groundOuts': 3,
#       'airOuts': 2,
#       'runs': 1,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 1,
#       'baseOnBalls': 2,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 5,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 35,
#       'inningsPitched': '2.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'battersFaced': 8,
#       'outs': 6,
#       'gamesPitched': 1,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 35,
#       'balls': 15,
#       'strikes': 20,
#       'strikePercentage': '.570',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'rbi': 1,
#       'gamesFinished': 0,
#       'runsScoredPer9': '4.50',
#       'homeRunsPer9': '0.00',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 1,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 1},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 2,
#       'putOuts': 0,
#       'errors': 0,
#       'chances': 2,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 1,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
# ...
#       'sacFlies': 3,
#       'passedBall': 0,
#       'popOuts': 10,
#       'lineOuts': 16},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 3,
#       'putOuts': 1,
#       'errors': 0,
#       'chances': 4,
#       'fielding': '1.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '1',
#       'name': 'Pitcher',
#       'type': 'Pitcher',
#       'abbreviation': 'P'}]},
#    'ID593871': {'person': {'id': 593871,
#      'fullName': 'Jorge Polanco',
#      'link': '/api/v1/people/593871',
#      'boxscoreName': 'Polanco'},
#     'jerseyNumber': '7',
#     'position': {'code': '10',
#      'name': 'Designated Hitter',
#      'type': 'Hitter',
#      'abbreviation': 'DH'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 136,
#     'battingOrder': '500',
#     'stats': {'batting': {'summary': '1-3 | BB, 2 R',
#       'gamesPlayed': 1,
#       'flyOuts': 2,
#       'groundOuts': 1,
#       'airOuts': 2,
#       'runs': 2,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 1,
#       'intentionalWalks': 0,
#       'hits': 1,
#       'hitByPitch': 0,
#       'atBats': 3,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 5,
#       'totalBases': 1,
#       'rbi': 0,
#       'leftOnBase': 1,
#       'sacBunts': 1,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 0,
#       'errors': 0,
#       'chances': 0,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 79,
#       'flyOuts': 43,
#       'groundOuts': 77,
#       'airOuts': 87,
#       'runs': 35,
#       'doubles': 13,
#       'triples': 0,
#       'homeRuns': 15,
#       'strikeOuts': 41,
#       'baseOnBalls': 21,
#       'intentionalWalks': 0,
#       'hits': 69,
#       'hitByPitch': 3,
#       'avg': '.257',
#       'atBats': 269,
#       'obp': '.314',
#       'slg': '.472',
#       'ops': '.786',
#       'caughtStealing': 2,
#       'stolenBases': 3,
#       'stolenBasePercentage': '.600',
#       'groundIntoDoublePlay': 5,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 298,
#       'totalBases': 127,
#       'rbi': 44,
#       'leftOnBase': 99,
#       'sacBunts': 2,
#       'sacFlies': 3,
#       'babip': '.250',
#       'groundOutsToAirouts': '0.89',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '17.93',
#       'popOuts': 26,
#       'lineOuts': 18},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 28,
#       'putOuts': 17,
#       'errors': 0,
#       'chances': 45,
#       'fielding': '1.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '10',
#       'name': 'Designated Hitter',
#       'type': 'Hitter',
#       'abbreviation': 'DH'}]},
#    'ID670042': {'person': {'id': 670042,
#      'fullName': 'Luke Raley',
#      'link': '/api/v1/people/670042',
#      'boxscoreName': 'Raley, L'},
#     'jerseyNumber': '20',
#     'position': {'code': '3',
#      'name': 'First Base',
#      'type': 'Infielder',
#      'abbreviation': '1B'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 136,
#     'battingOrder': '600',
#     'stats': {'batting': {'summary': '1-1 | BB, RBI, R',
#       'gamesPlayed': 1,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 1,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 1,
#       'intentionalWalks': 0,
#       'hits': 1,
#       'hitByPitch': 0,
#       'atBats': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 2,
#       'totalBases': 1,
#       'rbi': 1,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 4,
#       'errors': 0,
#       'chances': 4,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 44,
#       'flyOuts': 14,
#       'groundOuts': 40,
#       'airOuts': 25,
#       'runs': 19,
#       'doubles': 6,
#       'triples': 0,
#       'homeRuns': 4,
#       'strikeOuts': 38,
#       'baseOnBalls': 16,
#       'intentionalWalks': 0,
#       'hits': 30,
#       'hitByPitch': 9,
#       'avg': '.229',
#       'atBats': 131,
#       'obp': '.350',
#       'slg': '.366',
#       'ops': '.716',
#       'caughtStealing': 1,
#       'stolenBases': 2,
#       'stolenBasePercentage': '.667',
#       'groundIntoDoublePlay': 2,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 158,
#       'totalBases': 48,
#       'rbi': 18,
#       'leftOnBase': 65,
#       'sacBunts': 1,
#       'sacFlies': 1,
#       'babip': '.289',
#       'groundOutsToAirouts': '1.60',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '32.75',
#       'popOuts': 5,
#       'lineOuts': 6},
#      'pitching': {'gamesPlayed': 0,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'atBats': 0,
#       'obp': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 0,
#       'era': '-.--',
#       'inningsPitched': '0.0',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 0,
#       'whip': '-',
#       'battersFaced': 0,
#       'outs': 0,
#       'gamesPitched': 0,
#       'completeGames': 0,
#       'shutouts': 0,
#       'balls': 0,
#       'strikes': 0,
#       'strikePercentage': '-.--',
#       'hitBatsmen': 0,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '-.--',
#       'rbi': 0,
#       'winPercentage': '.---',
#       'pitchesPerInning': '-.--',
#       'gamesFinished': 0,
#       'strikeoutWalkRatio': '-.--',
#       'strikeoutsPer9Inn': '-.--',
#       'walksPer9Inn': '-.--',
#       'hitsPer9Inn': '-.--',
#       'runsScoredPer9': '-.--',
#       'homeRunsPer9': '-.--',
#       'inheritedRunners': 0,
#       'inheritedRunnersScored': 0,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'gamesStarted': 1,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 13,
#       'putOuts': 144,
#       'errors': 1,
#       'chances': 158,
#       'fielding': '.994',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '3',
#       'name': 'First Base',
#       'type': 'Infielder',
#       'abbreviation': '1B'}]},
#    'ID672841': {'person': {'id': 672841,
#      'fullName': 'Carlos Vargas',
#      'link': '/api/v1/people/672841',
#      'boxscoreName': 'Vargas'},
#     'jerseyNumber': '54',
#     'position': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'status': {'code': 'A', 'description': 'Active'},
#     'parentTeamId': 136,
#     'stats': {'batting': {},
#      'pitching': {'summary': '1.1 IP, 3 ER, 0 K, 0 BB',
#       'gamesPlayed': 1,
#       'gamesStarted': 0,
#       'flyOuts': 0,
#       'groundOuts': 3,
#       'airOuts': 0,
#       'runs': 3,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 3,
#       'hitByPitch': 2,
#       'atBats': 6,
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'numberOfPitches': 17,
#       'inningsPitched': '1.1',
#       'wins': 0,
#       'losses': 0,
#       'saves': 0,
#       'saveOpportunities': 0,
#       'holds': 0,
#       'blownSaves': 0,
#       'earnedRuns': 3,
#       'battersFaced': 8,
#       'outs': 4,
#       'gamesPitched': 1,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 17,
#       'balls': 5,
#       'strikes': 12,
#       'strikePercentage': '.710',
#       'hitBatsmen': 2,
#       'balks': 0,
#       'wildPitches': 0,
#       'pickoffs': 0,
#       'rbi': 2,
#       'gamesFinished': 0,
#       'runsScoredPer9': '20.25',
#       'homeRunsPer9': '0.00',
#       'inheritedRunners': 2,
#       'inheritedRunnersScored': 1,
#       'catchersInterference': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'passedBall': 0,
#       'popOuts': 0,
#       'lineOuts': 0},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 0,
#       'putOuts': 0,
#       'errors': 0,
#       'chances': 0,
#       'fielding': '.000',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'seasonStats': {'batting': {'gamesPlayed': 0,
#       'flyOuts': 0,
#       'groundOuts': 0,
#       'airOuts': 0,
#       'runs': 0,
#       'doubles': 0,
#       'triples': 0,
#       'homeRuns': 0,
#       'strikeOuts': 0,
#       'baseOnBalls': 0,
#       'intentionalWalks': 0,
#       'hits': 0,
#       'hitByPitch': 0,
#       'avg': '.000',
#       'atBats': 0,
#       'obp': '.000',
#       'slg': '.000',
#       'ops': '.000',
#       'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'groundIntoDoublePlay': 0,
#       'groundIntoTriplePlay': 0,
#       'plateAppearances': 0,
#       'totalBases': 0,
#       'rbi': 0,
#       'leftOnBase': 0,
#       'sacBunts': 0,
#       'sacFlies': 0,
#       'babip': '.---',
#       'groundOutsToAirouts': '-.--',
#       'catchersInterference': 0,
#       'pickoffs': 0,
#       'atBatsPerHomeRun': '-.--',
#       'popOuts': 0,
#       'lineOuts': 0},
#      'pitching': {'gamesPlayed': 43,
#       'gamesStarted': 0,
#       'flyOuts': 25,
#       'groundOuts': 53,
#       'airOuts': 47,
#       'runs': 25,
#       'doubles': 5,
#       'triples': 1,
#       'homeRuns': 5,
#       'strikeOuts': 32,
#       'baseOnBalls': 19,
#       'intentionalWalks': 4,
#       'hits': 49,
#       'hitByPitch': 3,
#       'atBats': 179,
#       'obp': '.351',
#       'caughtStealing': 2,
#       'stolenBases': 6,
#       'stolenBasePercentage': '.750',
#       'numberOfPitches': 683,
#       'era': '3.91',
#       'inningsPitched': '46.0',
#       'wins': 3,
#       'losses': 5,
#       'saves': 1,
#       'saveOpportunities': 6,
#       'holds': 11,
#       'blownSaves': 5,
#       'earnedRuns': 20,
#       'whip': '1.48',
#       'battersFaced': 203,
#       'outs': 138,
#       'gamesPitched': 43,
#       'completeGames': 0,
#       'shutouts': 0,
#       'pitchesThrown': 683,
#       'balls': 244,
#       'strikes': 439,
#       'strikePercentage': '.640',
#       'hitBatsmen': 3,
#       'balks': 0,
#       'wildPitches': 2,
#       'pickoffs': 0,
#       'groundOutsToAirouts': '1.13',
#       'rbi': 2,
#       'winPercentage': '.375',
#       'pitchesPerInning': '14.85',
#       'gamesFinished': 5,
#       'strikeoutWalkRatio': '1.68',
#       'strikeoutsPer9Inn': '6.26',
#       'walksPer9Inn': '3.72',
#       'hitsPer9Inn': '9.59',
#       'runsScoredPer9': '4.89',
#       'homeRunsPer9': '0.98',
#       'inheritedRunners': 13,
#       'inheritedRunnersScored': 6,
#       'catchersInterference': 0,
#       'sacBunts': 1,
#       'sacFlies': 1,
#       'passedBall': 0,
#       'popOuts': 6,
#       'lineOuts': 16},
#      'fielding': {'caughtStealing': 0,
#       'stolenBases': 0,
#       'stolenBasePercentage': '.---',
#       'assists': 5,
#       'putOuts': 4,
#       'errors': 1,
#       'chances': 10,
#       'fielding': '.900',
#       'passedBall': 0,
#       'pickoffs': 0}},
#     'gameStatus': {'isCurrentBatter': False,
#      'isCurrentPitcher': False,
#      'isOnBench': False,
#      'isSubstitute': False},
#     'allPositions': [{'code': '1',
#       'name': 'Pitcher',
#       'type': 'Pitcher',
#       'abbreviation': 'P'}]}},
#   'batters': [641487,
#    677594,
#    663728,
#    668227,
#    593871,
#    670042,
#    456781,
#    664238,
#    686527,
#    810938,
#    670156,
#    702284,
#    688138,
#    672841,
#    642100,
#    668984,
#    663423,
#    662253,
#    666374,
#    660825],
#   'pitchers': [688138, 672841, 642100, 668984, 663423, 662253, 666374, 660825],
#   'bench': [641598],
#   'bullpen': [686228, 622491, 669302, 669923, 693433],
#   'battingOrder': [641487,
#    677594,
#    663728,
#    668227,
#    593871,
#    664238,
#    686527,
#    670156,
#    702284],
#   'info': [{'title': 'BATTING',
#     'fieldList': [{'label': '2B',
#       'value': 'Canzone (6, McCullers Jr.); Arozarena (22, Abreu, B).'},
#      {'label': 'TB',
#       'value': 'Arozarena 3; Canzone 2; Polanco; Raley, L; Rodríguez, J; Young.'},
#      {'label': 'RBI',
#       'value': 'Canzone 2 (12); Moore, D (19); Raley, L (18); Williamson (19); Young (12).'},
#      {'label': '2-out RBI', 'value': 'Raley, L; Canzone 2.'},
#      {'label': 'Runners left in scoring position, 2 out',
#       'value': 'Canzone; Crawford, J 2; Williamson; Young; Mastrobuoni.'},
#      {'label': 'SAC', 'value': 'Mastrobuoni; Polanco.'},
#      {'label': 'GIDP', 'value': 'Raleigh.'},
#      {'label': 'Team RISP', 'value': '3-for-12.'},
#      {'label': 'Team LOB', 'value': '9.'}]},
#    {'title': 'BASERUNNING',
#     'fieldList': [{'label': 'SB',
#       'value': 'Moore, D (10, 2nd base off Abreu, B/Caratini).'}]},
#    {'title': 'FIELDING',
#     'fieldList': [{'label': 'E', 'value': 'Rodríguez, J (3, fielding).'},
#      {'label': 'DP', 'value': '(Crawford, J-Raley, L).'}]}],
#   'note': [{'label': 'a', 'value': 'Struck out for Raley, L in the 6th.'},
#    {'label': 'b', 'value': 'Struck out for Williamson in the 8th.'},
#    {'label': '1', 'value': 'Ran for Solano in the 8th.'}]}}
