# %%
import pandas as pd
import os
import glob

def combine_csv_files(folder_path, output_file):
    """
    Combine all CSV files in a folder into one CSV file
    
    Args:
        folder_path (str): Path to folder containing CSV files
        output_file (str): Path for the combined output CSV file
    """
    # Get all CSV files in the folder
    csv_files = glob.glob(os.path.join(folder_path, "*.csv"))
    
    if not csv_files:
        print(f"No CSV files found in {folder_path}")
        return
    
    print(f"Found {len(csv_files)} CSV files to combine:")
    for file in csv_files:
        print(f"  - {os.path.basename(file)}")
    
    # Read and combine all CSV files
    combined_data = []
    total_rows = 0
    
    for file in csv_files:
        try:
            df = pd.read_csv(file)
            combined_data.append(df)
            total_rows += len(df)
            print(f"  - Loaded {len(df)} rows from {os.path.basename(file)}")
        except Exception as e:
            print(f"  - Error reading {file}: {e}")
    
    if combined_data:
        # Combine all DataFrames
        combined_df = pd.concat(combined_data, ignore_index=True)
        
        # Save to output file
        combined_df.to_csv(output_file, index=False)
        print(f"\nCombined {len(csv_files)} files into {output_file}")
        print(f"Total rows: {total_rows}")
        print(f"Combined DataFrame shape: {combined_df.shape}")
    else:
        print("No data to combine")

# Example usage for your boxscore files
if __name__ == "__main__":
    # Or combine game files
    folder_path = "data/csv/games"
    output_file = "data/csv/games/combined_games.csv"
    
    combine_csv_files(folder_path, output_file)
# Out:
# Found 113 CSV files to combine:
#   - mlb_games_2025-03-27.csv
#   - mlb_games_2025-03-28.csv
#   - mlb_games_2025-03-29.csv
#   - mlb_games_2025-03-30.csv
#   - mlb_games_2025-03-31.csv
#   - mlb_games_2025-04-01.csv
#   - mlb_games_2025-04-02.csv
#   - mlb_games_2025-04-03.csv
#   - mlb_games_2025-04-04.csv
#   - mlb_games_2025-04-05.csv
#   - mlb_games_2025-04-06.csv
#   - mlb_games_2025-04-07.csv
#   - mlb_games_2025-04-08.csv
#   - mlb_games_2025-04-09.csv
#   - mlb_games_2025-04-10.csv
#   - mlb_games_2025-04-11.csv
#   - mlb_games_2025-04-12.csv
#   - mlb_games_2025-04-13.csv
#   - mlb_games_2025-04-14.csv
#   - mlb_games_2025-04-15.csv
#   - mlb_games_2025-04-16.csv
#   - mlb_games_2025-04-17.csv
#   - mlb_games_2025-04-18.csv
#   - mlb_games_2025-04-19.csv
#   - mlb_games_2025-04-20.csv
#   - mlb_games_2025-04-21.csv
#   - mlb_games_2025-04-22.csv
#   - mlb_games_2025-04-23.csv
#   - mlb_games_2025-04-24.csv
#   - mlb_games_2025-04-25.csv
#   - mlb_games_2025-04-26.csv
#   - mlb_games_2025-04-27.csv
#   - mlb_games_2025-04-28.csv
#   - mlb_games_2025-04-29.csv
#   - mlb_games_2025-04-30.csv
#   - mlb_games_2025-05-01.csv
#   - mlb_games_2025-05-02.csv
#   - mlb_games_2025-05-03.csv
#   - mlb_games_2025-05-04.csv
#   - mlb_games_2025-05-05.csv
#   - mlb_games_2025-05-06.csv
#   - mlb_games_2025-05-07.csv
#   - mlb_games_2025-05-08.csv
#   - mlb_games_2025-05-09.csv
#   - mlb_games_2025-05-10.csv
#   - mlb_games_2025-05-11.csv
#   - Loaded 14 rows from mlb_games_2025-04-05.csv
#   - Loaded 15 rows from mlb_games_2025-04-06.csv
#   - Loaded 11 rows from mlb_games_2025-04-07.csv
#   - Loaded 15 rows from mlb_games_2025-04-08.csv
#   - Loaded 15 rows from mlb_games_2025-04-09.csv
#   - Loaded 6 rows from mlb_games_2025-04-10.csv
#   - Loaded 13 rows from mlb_games_2025-04-11.csv
#   - Loaded 15 rows from mlb_games_2025-04-12.csv
#   - Loaded 15 rows from mlb_games_2025-04-13.csv
#   - Loaded 10 rows from mlb_games_2025-04-14.csv
#   - Loaded 15 rows from mlb_games_2025-04-15.csv
#   - Loaded 15 rows from mlb_games_2025-04-16.csv
#   - Loaded 10 rows from mlb_games_2025-04-17.csv
#   - Loaded 14 rows from mlb_games_2025-04-18.csv
#   - Loaded 15 rows from mlb_games_2025-04-19.csv
#   - Loaded 16 rows from mlb_games_2025-04-20.csv
#   - Loaded 8 rows from mlb_games_2025-04-21.csv
#   - Loaded 15 rows from mlb_games_2025-04-22.csv
#   - Loaded 14 rows from mlb_games_2025-04-23.csv
#   - Loaded 8 rows from mlb_games_2025-04-24.csv
#   - Loaded 13 rows from mlb_games_2025-04-25.csv
#   - Loaded 16 rows from mlb_games_2025-04-26.csv
#   - Loaded 16 rows from mlb_games_2025-04-27.csv
#   - Loaded 8 rows from mlb_games_2025-04-28.csv
#   - Loaded 14 rows from mlb_games_2025-04-29.csv
#   - Loaded 16 rows from mlb_games_2025-04-30.csv
#   - Loaded 11 rows from mlb_games_2025-05-01.csv
#   - Loaded 15 rows from mlb_games_2025-05-02.csv
#   - Loaded 14 rows from mlb_games_2025-05-03.csv
#   - Loaded 15 rows from mlb_games_2025-05-04.csv
#   - Loaded 9 rows from mlb_games_2025-05-05.csv
#   - Loaded 15 rows from mlb_games_2025-05-06.csv
#   - Loaded 15 rows from mlb_games_2025-05-07.csv
#   - Loaded 9 rows from mlb_games_2025-05-08.csv
#   - Loaded 15 rows from mlb_games_2025-05-09.csv
#   - Loaded 15 rows from mlb_games_2025-05-10.csv
#   - Loaded 15 rows from mlb_games_2025-05-11.csv
#   - Loaded 11 rows from mlb_games_2025-05-12.csv
#   - Loaded 13 rows from mlb_games_2025-05-13.csv
#   - Loaded 17 rows from mlb_games_2025-05-14.csv
#   - Loaded 6 rows from mlb_games_2025-05-15.csv
#   - Loaded 15 rows from mlb_games_2025-05-16.csv
#   - Loaded 15 rows from mlb_games_2025-05-17.csv
#   - Loaded 15 rows from mlb_games_2025-05-18.csv
#   - Loaded 12 rows from mlb_games_2025-05-19.csv
#   - Loaded 14 rows from mlb_games_2025-05-20.csv
#   - Loaded 15 rows from mlb_games_2025-05-21.csv
#   - Loaded 8 rows from mlb_games_2025-05-22.csv
#   - Loaded 15 rows from mlb_games_2025-05-23.csv
#   - Loaded 16 rows from mlb_games_2025-05-24.csv
#   - Loaded 15 rows from mlb_games_2025-05-25.csv
#   - Loaded 12 rows from mlb_games_2025-05-26.csv
#   - Loaded 15 rows from mlb_games_2025-05-27.csv
#   - Loaded 14 rows from mlb_games_2025-05-28.csv
#   - Loaded 5 rows from mlb_games_2025-05-29.csv
#   - Loaded 15 rows from mlb_games_2025-05-30.csv
#   - Loaded 15 rows from mlb_games_2025-05-31.csv
#   - Loaded 15 rows from mlb_games_2025-06-01.csv
#   - Loaded 7 rows from mlb_games_2025-06-02.csv
#   - Loaded 15 rows from mlb_games_2025-06-03.csv
#   - Loaded 14 rows from mlb_games_2025-06-04.csv
#   - Loaded 13 rows from mlb_games_2025-06-05.csv
#   - Loaded 15 rows from mlb_games_2025-06-06.csv
#   - Loaded 16 rows from mlb_games_2025-06-07.csv
#   - Loaded 15 rows from mlb_games_2025-06-08.csv
#   - Loaded 9 rows from mlb_games_2025-06-09.csv
#   - Loaded 15 rows from mlb_games_2025-06-10.csv
#   - Loaded 15 rows from mlb_games_2025-06-11.csv
#   - Loaded 8 rows from mlb_games_2025-06-12.csv
#   - Loaded 15 rows from mlb_games_2025-06-13.csv
#   - Loaded 15 rows from mlb_games_2025-06-14.csv
#   - Loaded 15 rows from mlb_games_2025-06-15.csv
#   - Loaded 7 rows from mlb_games_2025-06-16.csv
#   - Loaded 15 rows from mlb_games_2025-06-17.csv
#   - Loaded 11 rows from mlb_games_2025-06-18.csv
#   - Loaded 16 rows from mlb_games_2025-06-19.csv
#   - Loaded 15 rows from mlb_games_2025-06-20.csv
#   - Loaded 15 rows from mlb_games_2025-06-21.csv
#   - Loaded 15 rows from mlb_games_2025-06-22.csv
#   - Loaded 9 rows from mlb_games_2025-06-23.csv
#   - Loaded 15 rows from mlb_games_2025-06-24.csv
#   - Loaded 15 rows from mlb_games_2025-06-25.csv
#   - Loaded 9 rows from mlb_games_2025-06-26.csv
#   - Loaded 15 rows from mlb_games_2025-06-27.csv
#   - Loaded 15 rows from mlb_games_2025-06-28.csv
#   - Loaded 15 rows from mlb_games_2025-06-29.csv
#   - Loaded 8 rows from mlb_games_2025-06-30.csv
#   - Loaded 12 rows from mlb_games_2025-07-01.csv
#   - Loaded 19 rows from mlb_games_2025-07-02.csv
#   - Loaded 10 rows from mlb_games_2025-07-03.csv
#   - Loaded 15 rows from mlb_games_2025-07-04.csv
#   - Loaded 15 rows from mlb_games_2025-07-05.csv
#   - Loaded 15 rows from mlb_games_2025-07-06.csv
#   - Loaded 65 rows from mlb_games_2025-07-06_to_2025-07-18.csv
#   - Loaded 10 rows from mlb_games_2025-07-07.csv
#   - Loaded 14 rows from mlb_games_2025-07-08.csv
#   - Loaded 14 rows from mlb_games_2025-07-09.csv
#   - Loaded 10 rows from mlb_games_2025-07-10.csv
#   - Loaded 16 rows from mlb_games_2025-07-11.csv
#   - Loaded 15 rows from mlb_games_2025-07-12.csv
#   - Loaded 15 rows from mlb_games_2025-07-13.csv
#   - Loaded 1 rows from mlb_games_2025-07-15.csv
#   - Loaded 15 rows from mlb_games_2025-07-18.csv
#   - Loaded 15 rows from mlb_games_2025-07-19.csv
#
# Combined 113 files into data/csv/games/combined_games.csv
# Total rows: 1538
# Combined DataFrame shape: (1538, 5)
