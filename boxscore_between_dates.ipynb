# %% [markdown]
# This code will:
#
# Loop through each date from July 6, 2025 to July 18, 2025
# For each date, call your existing fetch_and_save_final_boxscores() function
# Save individual files for each day:
# JSON: data/json/boxscores/mlb_boxscores_{date}.json
# CSV: data/csv/boxscores/mlb_boxscores_{date}.csv
# Create a combined CSV with all batting data from the entire date range
# Handle errors gracefully if any dates fail to process

# %%
import requests
import pandas as pd
import json
import os
from datetime import datetime, timedelta

def fetch_and_save_final_boxscores(date_str):
    csv_path = f'data/csv/games/mlb_games_{date_str}.csv'
    json_path = f'data/json/boxscores/mlb_boxscores_{date_str}.json'
    csv_output_path = f'data/csv/boxscores/mlb_boxscores_{date_str}.csv'

    if not os.path.exists(csv_path):
        print(f"CSV file not found: {csv_path}")
        return

    games_df = pd.read_csv(csv_path)
    all_boxscores = []
    
    for game_pk in games_df['gamePk']:
        url = f'https://statsapi.mlb.com/api/v1/game/{game_pk}/boxscore'
        response = requests.get(url)
        if response.status_code == 200:
            boxscore_data = response.json()
            all_boxscores.append({'gamePk': game_pk, 'boxscore': boxscore_data})
        else:
            all_boxscores.append({'gamePk': game_pk, 'boxscore': None})
    
    # Ensure directories exist
    os.makedirs(os.path.dirname(json_path), exist_ok=True)
    os.makedirs('data/csv/boxscores', exist_ok=True)
    
    # Save JSON
    with open(json_path, 'w') as f:
        json.dump(all_boxscores, f, indent=2)
    
    # Convert to CSV - flatten batting data for all players
    batting_rows = []
    for game in all_boxscores:
        if game['boxscore']:
            for team_type in ['home', 'away']:
                team = game['boxscore']['teams'][team_type]
                batters = team.get('batters', [])
                players = team.get('players', {})
                
                for batter_id in batters:
                    player_key = f"ID{batter_id}"
                    player = players.get(player_key, {})
                    if player:
                        person = player.get('person', {})
                        stats = player.get('stats', {}).get('batting', {})
                        
                        row = {
                            'gamePk': game['gamePk'],
                            'team': team['team']['name'],
                            'team_type': team_type,
                            'player_id': person.get('id'),
                            'player_name': person.get('fullName'),
                            'batting_order': player.get('battingOrder'),
                            'gamesPlayed': stats.get('gamesPlayed'),
                            'atBats': stats.get('atBats'),
                            'hits': stats.get('hits'),
                            'runs': stats.get('runs'),
                            'doubles': stats.get('doubles'),
                            'triples': stats.get('triples'),
                            'homeRuns': stats.get('homeRuns'),
                            'rbi': stats.get('rbi'),
                            'baseOnBalls': stats.get('baseOnBalls'),
                            'strikeOuts': stats.get('strikeOuts'),
                            'leftOnBase': stats.get('leftOnBase'),
                        }
                        batting_rows.append(row)
    
    # Create and save CSV
    df = pd.DataFrame(batting_rows)
    df.to_csv(csv_output_path, index=False)
    print(f"Saved boxscore data to {csv_output_path}")

# Define date range
start_date = datetime(2025, 3, 27)
end_date = datetime(2025, 5, 31)

# Generate list of dates
date_range = []
current_date = start_date
while current_date <= end_date:
    date_range.append(current_date.strftime('%Y-%m-%d'))
    current_date += timedelta(days=1)

print(f"Processing boxscores for dates: {date_range}")

# Process each date
all_batting_data = []
for date_str in date_range:
    print(f"Processing boxscores for {date_str}...")
    
    try:
        fetch_and_save_final_boxscores(date_str)
        
        # Read the individual CSV to add to combined dataset
        csv_path = f'data/csv/boxscores/mlb_boxscores_{date_str}.csv'
        if os.path.exists(csv_path):
            daily_df = pd.read_csv(csv_path)
            daily_df['date'] = date_str
            all_batting_data.append(daily_df)
            print(f"  - Processed {len(daily_df)} batting records for {date_str}")
        
    except Exception as e:
        print(f"  - Error processing {date_str}: {e}")

# Combine all batting data into one master CSV
if all_batting_data:
    combined_df = pd.concat(all_batting_data, ignore_index=True)
    combined_df.to_csv('data/csv/boxscores/mlb_boxscores_2025-07-06_to_2025-07-18.csv', index=False)
    print(f"\nCombined boxscore data saved: {len(combined_df)} total batting records")
    print(f"File: data/csv/boxscores/mlb_boxscores_2025-07-06_to_2025-07-18.csv")
else:
    print("No boxscore data found for the date range")
# Out:
# Processing boxscores for dates: ['2025-03-27', '2025-03-28', '2025-03-29', '2025-03-30', '2025-03-31', '2025-04-01', '2025-04-02', '2025-04-03', '2025-04-04', '2025-04-05', '2025-04-06', '2025-04-07', '2025-04-08', '2025-04-09', '2025-04-10', '2025-04-11', '2025-04-12', '2025-04-13', '2025-04-14', '2025-04-15', '2025-04-16', '2025-04-17', '2025-04-18', '2025-04-19', '2025-04-20', '2025-04-21', '2025-04-22', '2025-04-23', '2025-04-24', '2025-04-25', '2025-04-26', '2025-04-27', '2025-04-28', '2025-04-29', '2025-04-30', '2025-05-01', '2025-05-02', '2025-05-03', '2025-05-04', '2025-05-05', '2025-05-06', '2025-05-07', '2025-05-08', '2025-05-09', '2025-05-10', '2025-05-11', '2025-05-12', '2025-05-13', '2025-05-14', '2025-05-15', '2025-05-16', '2025-05-17', '2025-05-18', '2025-05-19', '2025-05-20', '2025-05-21', '2025-05-22', '2025-05-23', '2025-05-24', '2025-05-25', '2025-05-26', '2025-05-27', '2025-05-28', '2025-05-29', '2025-05-30', '2025-05-31']
# Processing boxscores for 2025-03-27...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-03-27.csv
#   - Processed 420 batting records for 2025-03-27
# Processing boxscores for 2025-03-28...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-03-28.csv
#   - Processed 259 batting records for 2025-03-28
# Processing boxscores for 2025-03-29...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-03-29.csv
#   - Processed 467 batting records for 2025-03-29
# Processing boxscores for 2025-03-30...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-03-30.csv
#   - Processed 386 batting records for 2025-03-30
# Processing boxscores for 2025-03-31...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-03-31.csv
#   - Processed 415 batting records for 2025-03-31
# Processing boxscores for 2025-04-01...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-01.csv
#   - Processed 380 batting records for 2025-04-01
# Processing boxscores for 2025-04-02...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-02.csv
#   - Processed 438 batting records for 2025-04-02
# Processing boxscores for 2025-04-03...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-03.csv
#   - Processed 144 batting records for 2025-04-03
# Processing boxscores for 2025-04-04...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-04.csv
#   - Processed 415 batting records for 2025-04-04
# Processing boxscores for 2025-04-05...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-05.csv
#   - Processed 401 batting records for 2025-04-05
# Processing boxscores for 2025-04-06...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-06.csv
#   - Processed 468 batting records for 2025-04-06
# Processing boxscores for 2025-04-07...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-07.csv
#   - Processed 295 batting records for 2025-04-07
# Processing boxscores for 2025-04-08...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-08.csv
#   - Processed 447 batting records for 2025-04-08
# Processing boxscores for 2025-04-09...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-09.csv
#   - Processed 452 batting records for 2025-04-09
# Processing boxscores for 2025-04-10...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-10.csv
#   - Processed 182 batting records for 2025-04-10
# Processing boxscores for 2025-04-11...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-11.csv
#   - Processed 369 batting records for 2025-04-11
# Processing boxscores for 2025-04-12...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-12.csv
#   - Processed 431 batting records for 2025-04-12
# Processing boxscores for 2025-04-13...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-13.csv
#   - Processed 434 batting records for 2025-04-13
# Processing boxscores for 2025-04-14...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-14.csv
#   - Processed 279 batting records for 2025-04-14
# Processing boxscores for 2025-04-15...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-15.csv
#   - Processed 425 batting records for 2025-04-15
# Processing boxscores for 2025-04-16...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-16.csv
#   - Processed 444 batting records for 2025-04-16
# Processing boxscores for 2025-04-17...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-17.csv
#   - Processed 288 batting records for 2025-04-17
# Processing boxscores for 2025-04-18...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-18.csv
#   - Processed 411 batting records for 2025-04-18
# Processing boxscores for 2025-04-19...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-19.csv
#   - Processed 440 batting records for 2025-04-19
# Processing boxscores for 2025-04-20...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-20.csv
#   - Processed 471 batting records for 2025-04-20
# Processing boxscores for 2025-04-21...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-21.csv
#   - Processed 219 batting records for 2025-04-21
# Processing boxscores for 2025-04-22...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-22.csv
#   - Processed 441 batting records for 2025-04-22
# Processing boxscores for 2025-04-23...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-23.csv
#   - Processed 421 batting records for 2025-04-23
# Processing boxscores for 2025-04-24...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-24.csv
#   - Processed 233 batting records for 2025-04-24
# Processing boxscores for 2025-04-25...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-25.csv
#   - Processed 368 batting records for 2025-04-25
# Processing boxscores for 2025-04-26...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-26.csv
#   - Processed 471 batting records for 2025-04-26
# Processing boxscores for 2025-04-27...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-27.csv
#   - Processed 454 batting records for 2025-04-27
# Processing boxscores for 2025-04-28...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-28.csv
#   - Processed 240 batting records for 2025-04-28
# Processing boxscores for 2025-04-29...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-29.csv
#   - Processed 402 batting records for 2025-04-29
# Processing boxscores for 2025-04-30...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-04-30.csv
#   - Processed 471 batting records for 2025-04-30
# Processing boxscores for 2025-05-01...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-01.csv
#   - Processed 318 batting records for 2025-05-01
# Processing boxscores for 2025-05-02...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-02.csv
#   - Processed 428 batting records for 2025-05-02
# Processing boxscores for 2025-05-03...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-03.csv
#   - Processed 401 batting records for 2025-05-03
# Processing boxscores for 2025-05-04...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-04.csv
#   - Processed 455 batting records for 2025-05-04
# Processing boxscores for 2025-05-05...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-05.csv
#   - Processed 265 batting records for 2025-05-05
# Processing boxscores for 2025-05-06...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-06.csv
#   - Processed 456 batting records for 2025-05-06
# Processing boxscores for 2025-05-07...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-07.csv
#   - Processed 443 batting records for 2025-05-07
# Processing boxscores for 2025-05-08...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-08.csv
#   - Processed 262 batting records for 2025-05-08
# Processing boxscores for 2025-05-09...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-09.csv
#   - Processed 440 batting records for 2025-05-09
# Processing boxscores for 2025-05-10...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-10.csv
#   - Processed 443 batting records for 2025-05-10
# Processing boxscores for 2025-05-11...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-11.csv
#   - Processed 440 batting records for 2025-05-11
# Processing boxscores for 2025-05-12...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-12.csv
#   - Processed 319 batting records for 2025-05-12
# Processing boxscores for 2025-05-13...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-13.csv
#   - Processed 394 batting records for 2025-05-13
# Processing boxscores for 2025-05-14...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-14.csv
#   - Processed 509 batting records for 2025-05-14
# Processing boxscores for 2025-05-15...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-15.csv
#   - Processed 154 batting records for 2025-05-15
# Processing boxscores for 2025-05-16...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-16.csv
#   - Processed 432 batting records for 2025-05-16
# Processing boxscores for 2025-05-17...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-17.csv
#   - Processed 447 batting records for 2025-05-17
# Processing boxscores for 2025-05-18...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-18.csv
#   - Processed 424 batting records for 2025-05-18
# Processing boxscores for 2025-05-19...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-19.csv
#   - Processed 345 batting records for 2025-05-19
# Processing boxscores for 2025-05-20...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-20.csv
#   - Processed 404 batting records for 2025-05-20
# Processing boxscores for 2025-05-21...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-21.csv
#   - Processed 448 batting records for 2025-05-21
# Processing boxscores for 2025-05-22...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-22.csv
#   - Processed 249 batting records for 2025-05-22
# Processing boxscores for 2025-05-23...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-23.csv
#   - Processed 454 batting records for 2025-05-23
# Processing boxscores for 2025-05-24...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-24.csv
#   - Processed 465 batting records for 2025-05-24
# Processing boxscores for 2025-05-25...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-25.csv
#   - Processed 427 batting records for 2025-05-25
# Processing boxscores for 2025-05-26...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-26.csv
#   - Processed 343 batting records for 2025-05-26
# Processing boxscores for 2025-05-27...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-27.csv
#   - Processed 432 batting records for 2025-05-27
# Processing boxscores for 2025-05-28...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-28.csv
#   - Processed 410 batting records for 2025-05-28
# Processing boxscores for 2025-05-29...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-29.csv
#   - Processed 156 batting records for 2025-05-29
# Processing boxscores for 2025-05-30...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-30.csv
#   - Processed 428 batting records for 2025-05-30
# Processing boxscores for 2025-05-31...
# Saved boxscore data to data/csv/boxscores/mlb_boxscores_2025-05-31.csv
#   - Processed 436 batting records for 2025-05-31
#
# Combined boxscore data saved: 25308 total batting records
# File: data/csv/boxscores/mlb_boxscores_2025-07-06_to_2025-07-18.csv
